# %% [markdown]
#   <h1><center>ECMWF MOOC MACHINE LEARNING IN WEATHER AND CLIMATE</center></h1>
#
#    <h2><center>Tier 3: Practical ML application in weather and climate - OBSERVATIONS</center></h2>
#
#    <h2><center> Exercise on how to build a simple ANN model for satellite precipitation retrieval using passive microwave measurements </center></h2>
#
#  <h3><center>Created by: Daniele Casella, Paolo Sanò, Leo Pio D'Adderio, Riccardo D'Ercole </center></h3>
#   <h3><center> CNR-ISAC, Rome Italy</center></h3>

# %% [markdown]
# ## Introduction
# This Jupiter Notebook is on how to build a simple Artificialt Neural Network (ANN) (Multilayer Perceptrons) for surface precipitation rate estimation using the GPM Microwave Imager (GMI) measurements as input. The training dataset is a small-size osbervational dataset built from coincident measurements of the GMI and the Dual-frequency Precipitation Radar (DPR) on board the NASA/JAXA GPM-Core Observatory. The ANN architecture is pre-defined and an optimal set of parameters for the training phase is provided. The goal is to define the ANN (the weights) by minimising the prediction error (the loss function) avoiding overfitting during training. As you go through this Jupiter Notebook, you will learn about GMI characteristics, definition of ANN architecture, key parameters in the training phase, minimisation of the loss function, and overfitting. The ANN model obtained will be applied to one case study.
#
# As First Task it is recommended that you go through the code and the plots provided, understanding the meaning of each step. As a second Task you may run the code, play with the parameters, and analyse the results. Please, consider that the training for each set of parameters can take a few minutes.
#
# you can run this code on [colab](https://colab.research.google.com/github/ecmwf-projects/mooc-machine-learning-weather-climate/blob/main/tier_3/observations/mooc_tier3_1_ml_sat_panegrossi_v4.ipynb)

# %% [markdown]
# ## Before starting: python and libraries installation
#
# ### Python
# Python 3 is required for running this code on your machine. The fastest way to have python is to install the [Anaconda Package](https://www.anaconda.com/products/individual).  By the way, python can be installed on all OS, there are versions of Anaconda for Linux Mac and Windows, however this code has been tested for Linux Ubuntu and windows 64 bit OS.
#
# Before starting you need to install some additional software and some python packages.
#
#
# ### Libraries installation
#
# The easiest way to get everything installed is to use conda (from a terminal or Anaconda Prompt in Windows) to create a new virtual environment:
#
#
# <p style="background:black">
# <code style="background:black;color:white">
#   user@user:/home/user$ conda create -n tf tensorflow pandas scikit-learn matplotlib basemap xarray netCDF4 h5netcdf h5py
#   user@user:/home/user$ conda activate tf
# </code>
# </p>
#
#
#
#
# ### Data download
#
#
# Before running the notebook you need to download some data:

# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=92e3e4a31d523cf7f383fe6d74037306f90c793647226590e86610e84a3973f7
#   Stored in directory: c:\users\paolo\appdata\local\pip\cache\wheels\04\5f\3e\46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
import wget
url = 'https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_3/observations/1C-R.GPM.GMI.XCAL2016-C.20200916-S130832-E144106.037225.V07A.HDF5'
filename = wget.download(url)
url = 'https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_3/observations/2A.GPM.GMI.GPROF2021v1.20200916-S130832-E144106.037225.V07A.HDF5'
filename = wget.download(url)
url = 'https://get.ecmwf.int/repository/mooc-machine-learning-weather-climate/tier_3/observations/dataset2_GMI_DPR_RR.nc'
filename = wget.download(url)
# Out:
# 100% [..........................................................................] 7440095 / 7440095

# %% [markdown]
# # GMI - GPM Microwave Imager
# The GMI is the most advanced spaceborne MW radiometer currently available, operating on the NASA/JAXA GPM Core Observatory (GPM-CO) launched in March 2014 (https://gpm.nasa.gov/). The GMI is a conical-scanning radiometer measuring vertically (V) and horizontally (H) polarised radiances in 13 channels between 10.65 and 183.31 GHz. Table 1 presents some details on GMI channels and their properties. In each channel the measured radiance, which is converted into brightness temperature (TB) for physical interpretation, results from the interaction of surface-emitted radiation with atmospheric water vapour and the liquid and solid hydrometeros within the cloud. Its 13 channels have different penetration ability in the cloud and are sensitive to different hydrometeor types and precipitation intensities. Complex retrieval algorithms convert the multichannel TBs in surface precipitation rate. There are several factors which makes the quantitative precipitation estimation from PMW radiometers (and from GMI) very challenging. Moreover, the relationhip between the multichannel TBs and surface rain rate is indirect and highly non linear, and machine learning techniques can be used to overcome some of these issues (e.g., Sanò et al., doi:10.3390/rs10071122) .
#
#
#  No. | Central frequency (GHz) | Polarisation | IFOV size
#  :-: | :-: | :-: | :-:
#  1 | 10.65 | V | 19x32 km
#  2 | 10.65 | H | 19x32 km
#  3 | 18.7 | V | 11x18 km
#  4 | 18.7 | H | 11x18 km
#  5 | 23.8 | V | 9.2x15 km
#  6 | 36.5 | V | 8.6x14 km
#  7 | 36.5 | H | 8.6x14 km
#  8 | 89.0 | V | 4.4x7.2 km
#  9 | 89.0 | H | 4.4x7.2 km
# 10 | 166.5 | V | 4.4x7.2 km
# 11 | 166.5 | H | 4.4x7.2 km
# 12 | 183.31 ± 3 | V | 4.4x7.2 km
# 13 | 183.31 ± 7 | V | 4.4x7.2 km
#
# <center><i>Table 1. GMI channels characteristics</i></center>

# %% [markdown]
# Now, we are ready to read the GMI files. The GMI files format is HDF5, and the "h5py" library has to be imported in order to be able to read the data. At the following link <a href="https://gpm.nasa.gov/resources/documents/file-specification-gpm-products/">GPM File Specification</a> you can find the document explaining the GMI file structure as well as the file structure of all Level 1 to Level 3 GPM products. The GPM products (including GMI) can be downloaded from <a href="https://storm.pps.eosdis.nasa.gov/storm/"> the NASA PPS Storm </a> website. In the following block we see how to open and read the content of a HDF5 file (i.e. the GMI file).

# %%
import h5py
gmi_file_path='./1C-R.GPM.GMI.XCAL2016-C.20200916-S130832-E144106.037225.V07A.HDF5'
hf=h5py.File(gmi_file_path,'r')
dataset1=hf['S1']
print(dataset1.keys())
# Out:
# <KeysViewHDF5 ['ScanTime', 'SCstatus', 'Latitude', 'Longitude', 'sunLocalTime', 'Quality', 'incidenceAngle', 'sunGlintAngle', 'incidenceAngleIndex', 'Tc']>

# %% [markdown]
# ### GMI TB Imagery
# In the following block, we are going to see how to create TB imagery for selected GMI channels.

# %%
# defining the funcion to plot
def plot_tb_map(TB,lat,lon,colorAxisMin,colorAxisMax):
    # set the lat/lon borders of the map
    latborders=[34,40]
    lonborders=[14,22]
    m = Basemap(projection='merc',
        resolution='l',
        lat_ts=20,
        llcrnrlat=latborders[0],urcrnrlat=latborders[1],\
        llcrnrlon=lonborders[0],urcrnrlon=lonborders[1])

    
#E set min/max values of the colorbar
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        im1 = m.pcolor(lon[:],lat[:],TB[:],shading='nearest',cmap='turbo',latlon=True,vmin=colorAxisMin,vmax=colorAxisMax)
    m.drawcoastlines()
    
# set parallels and meridians
    dparal=2 #separation in deg between drawn parallels
    parallels = np.arange(latborders[0],latborders[1],dparal)
    dmerid=2 #separation in deg between drawn meridians
    meridians = np.arange(lonborders[0],lonborders[1],dmerid)
    m.drawparallels(parallels,labels=[1,0,0,0],fontsize=15)
    m.drawmeridians(meridians,labels=[0,0,0,1],fontsize=15) 
# add colorbar.
    cbar = m.colorbar(location='right',pad="5%")
    cbar.set_label('K')



#windows users may need to set an environmental variable before
#import os
#os.environ["PROJ_LIB"] = 'C:'+os.sep+'Users'+os.sep+'Leo'+os.sep+'anaconda3'+os.sep+'Library'+os.sep+'share'; #with your anaconda installation path

import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap 
from mpl_toolkits.basemap import Basemap
import numpy as np
import h5py
import warnings

gmi_file_path='./1C-R.GPM.GMI.XCAL2016-C.20200916-S130832-E144106.037225.V07A.HDF5'
hf=h5py.File(gmi_file_path,'r')

dataset1=hf['S1']
dataset2=hf['S2']
lat1=hf['S1/Latitude'][:]
lon1=hf['S1/Longitude'][:]
TB=hf['S1/Tc'][:]
TB10v=TB[:,:,0]
TB10h=TB[:,:,1]
TB19v=TB[:,:,2]
TB19h=TB[:,:,3]
TB23v=TB[:,:,4]
TB37v=TB[:,:,5]
TB37h=TB[:,:,6]
TB89v=TB[:,:,7]
TB89h=TB[:,:,8]

lat2=hf['S2/Latitude'][:]
lon2=hf['S2/Longitude'][:]


TB=hf['S2/Tc'][:]
TB166v=TB[:,:,0]
TB166v[TB166v<0]=np.NaN
TB166h=TB[:,:,1]
hf.close()

fig = plt.figure(figsize=(24,16))
ax = fig.add_subplot(231)
plot_tb_map(TB10v,lat1,lon1,colorAxisMin=160,colorAxisMax=280)
plt.title('TB 10v')

ax = fig.add_subplot(232)
plot_tb_map(TB19v,lat1,lon1,colorAxisMin=180,colorAxisMax=280)
plt.title('TB 19v')

ax = fig.add_subplot(233)
plot_tb_map(TB23v,lat1,lon1,colorAxisMin=200,colorAxisMax=300)
plt.title('TB 23v')

ax = fig.add_subplot(234)
plot_tb_map(TB37v,lat1,lon1,colorAxisMin=210,colorAxisMax=280)
plt.title('TB 37v')

ax = fig.add_subplot(235)
plot_tb_map(TB89v,lat1,lon1,colorAxisMin=130,colorAxisMax=280)
plt.title('TB 89v')

ax = fig.add_subplot(236)
plot_tb_map(TB166v,lat1,lon1,colorAxisMin=140,colorAxisMax=300)
plt.title('TB 166v')

plt.show()

# %% [markdown]
# The panels show the GMI brightness temperatures (TBs) for the overpass which captured the Mediterranean Hurricane (Medicane) named Ianos on 16/09/2020 over the Ionian Sea between Southern Italy and Greece.
# The first row of panels shows the low frequency channels (< 30 GHz) affected mostly by the emission of radiation by the rain droplets, which results in higher TBs with respect to the radiatively cold sea surface background (warm areas in the imagery are associated to the precipitation in the rain bands around the cyclone center). The second row of panels shows the higher frequency channels, where the effect of the scattering by the ice on the observed TBs becomes visible as cold areas in the imagery. The scattering signal at 37 GHz and 89 GHz channel (low TBs) are due to the larger (and denser) frozen hydrometeors (hail/graupel) found in the convective cores, while at higher frequency the scattering is due to the smaller size/less dense ice in the upper cloud layers.  The following table summaries the properties of the six GMI frequencies (for further details please refer to D'Adderio et al.,10.1016/j.atmosres.2022.106174).
#
#  <table>
#
#   <tr>
#     <th style="text-align:center"> GMI channel</th>
#     <th style="text-align:center"> TB warmer than background</th>
#     <th style="text-align:center"> TB colder than background</th>
#   </tr>
#   <tr>
#     <td style="text-align:center"> 10 GHz</td>
#     <td style="text-align:center"> emission from large raindrops (lower rain layers) </td>
#     <td style="text-align:center"> - </td>
#   </tr>
#   <tr>
#     <td style="text-align:center"> 19 GHz</td>
#     <td style="text-align:center"> emission from large raindrops (rain)</td>
#     <td style="text-align:center"> - </td>
#   </tr>
#   <tr>
#     <td style="text-align:center"> 22 GHz</td>
#     <td style="text-align:center"> emission from large raindrops (rain)<br>emission from  water vapour</td>
#     <td style="text-align:center"> - </td>
#   </tr>
#   <tr>
#     <td style="text-align:center"> 37 GHz</td>
#     <td style="text-align:center"> emission from raindrops (rain)</td>
#     <td style="text-align:center"> Scattering by large and dense ice<br>(e.g. hail – deep convection)</td>
#   </tr>
#   <tr>
#     <td style="text-align:center"> 89 GHz</td>
#     <td style="text-align:center"> emission from water vapour<br>and cloud liquid water</td>
#     <td style="text-align:center"> Scattering by precipitating heavily rimed ice<br>(e.g., graupel – convection/deep convection)</td>
#   </tr>
#     <tr>
#     <td style="text-align:center"> 166 GHz</td>
#     <td style="text-align:center"> emission from water vapour<br>and cloud liquid water</td>
#     <td style="text-align:center"> Scattering by less dense ice<br>(snowflakes and aggregates – stratiform/convective precip)</td>
#   </tr>
# </table>
# <center><i>Table 2. Properties of some GMI channels related to clouds and precipitation.</i></center>

# %% [markdown]
# # Exercise: training a simple artificial neural network model
#
# This section explains how to train a Multilayer Perceptrons (MLP) Neural Network which predicts the target variable or label (surface rain rate) given a set of 13 pre-defined inputs or features (TBs). The model represents a simple Neural Network (NN) with two hidden layers and a final layer which is used to predict the target label.
#
# The section is composed by the following parts:
#
# 1) Data loading and conversion
# <br>
# 2) Dataset description
# <br>
# 3) Training and test data split
# <br>
# 4) Model training
# <br>
# 5) Model evaluation
# <br>
# 6) Further training of the model and overfitting
# <br>
# 7) Testing the trained model on the initial case study
#
# <div class="alert alert-block alert-warning">
# <b>Warning </b> The neural network that will be trained during this exercise is not suitable for scientific/operational purposes, the main limitation comes from the training dataset, which is very small (10 orbits) with respect to the ones used in scientific/operational algorithms, which can include hundreds of thousands of orbits and millions of pixels. Using very large training dataset is of paramount importance for obtaining a model that is general, i.e. a model that performs with the same accuracy when applied to the training or to an independent dataset.
# </div>

# %% [markdown]
# ### 1) Data loading and conversion
# First, we will import all the libraries which are necessary to this exercise.
# <br>
# After loading the data in xarray format, which is one of the most common Python libraries to process netcdf files, the data is transformed into tensors which is the standard format for training Machine Learning or Deep Learning models.
# <br> For the purpose of this exercise, we will use the Tensorflow framework, which is built on top of Keras Python library in order to train a Neural Network.
# <br> We observe that the features dataset have 61906 different records and 13 features, whereas the label dataset consist of one variable and 61906 records.

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import optimizers
from tensorflow.keras import utils
import tensorflow as tf
from sklearn.model_selection import train_test_split
import numpy as np
import xarray as xr
import warnings
from sklearn.preprocessing import StandardScaler
warnings.filterwarnings("ignore")

data_path = './dataset2_GMI_DPR_RR.nc'

ds = xr.open_dataset(data_path)

train_df = ds['tb'].to_dataframe().unstack()
target = ds['rr'].to_dataframe()

print('The shape of the features data is', train_df.shape)
print('The shape of the label data is', target.shape)

tensor_df = tf.convert_to_tensor(train_df, dtype=np.float)
label_df = tf.convert_to_tensor(target, dtype=np.float)
# Out:
# C:\Users\Paolo\anaconda3\envs\tf\lib\site-packages\ecmwflibs\__init__.py:83: UserWarning: DLL load failed while importing _ecmwflibs: Impossibile trovare la procedura specificata.
#   warnings.warn(str(e))
# The shape of the features data is (61906, 13)
# The shape of the label data is (61906, 1)

# %% [markdown]
# ### 2) Dataset description
#
# The dataset used for training and test of the NN is built from 10 GMI orbits (from 9th March 2014). The 13 features correspond exactly to the 13 GMI channels taken in the same order as in Table 1. The rainfall rate represents the target variable and has been obtained from the NASA GMI/DPR Level 2 precipitation product (2B-CMB). This algorithm combines GMI measurements with the reflectivity profiles measured by the Dual-frequency Precipitation Radar (DPR) on board the GPM Core Observatory, the first spaceborne radar operating at Ka and Ku band (see figure below) and provides vertical profiles of liquid and solid precipitation microphysics, and precipitation rate near the surface. Some details on the 2B-CMB algorithm can be found in <a href="https://gpm.nasa.gov/resources/documents/gpmdpr-level-2-algorithm-theoretical-basis-document-atbd/">GMI/DPR Level 2 Algorithm Theoretical Basis Document (ATBD) </a>.
#
# The GMI TBs and the DPR rainfall rates (from 2B-CMB) have been matched to build the dataset using a nearest neighbour approach. Only pixels over ocean and sea where rainfall has been observed (2B-CMB rainfall rate > 0 mm/h) are selected to build the dataset (for a total of 61906 pixels).
# ![title](https://rmets.onlinelibrary.wiley.com/cms/asset/6e4beac5-ee9c-4de1-a780-0c34bd06987b/qj3313-fig-0001-m.jpg)
# _from: Skofronick-Jackson et al. 2018 doi:10.1002/qj.3313_

# %% [markdown]
# ### 3) Training and test data split
# The objective of Machine Learning is to create a model which is able to learn from training data and consequently make consistent predictions in the presence of unseen data. In order to achieve this, the objective is to minimize a loss function. This is done by identifying a vector of model weights which minimizes the loss function.
# <br>
# <br>
# In order to train a Machine Learning model which is able to make successful predictions and therefore generalize sufficiently well in the presence of indipendent data coming from the similar distribution, a standard practice is to divide the dataset into __training__ and __test sets__. Generally speaking, the Machine Learning best practice suggests to retain about 80% of the dataset for training and the rest 20% for test purpose. Another common practice is to divide the dataset into three sets, namely train, test and validation in order to tune the model hyperparameters (using the test) and then validate the model on an independent set (validation).
# <br>
# <br> In our case, considering that our training set is quite small, we decide to opt for a __50%__ split between training and test set, to allow for a model testing on a comparable size dataset.

# %%
def split_dataset(dataset, label_dataset):
    
    choice=np.mod(range(0,len(tensor_df)),2)==0 #this variable is true for even positions in the obseravtions sequence 
    X_train = dataset[choice==0]
    X_test = dataset[choice]
    y_train = label_dataset[choice==0]
    y_test = label_dataset[choice]   
    
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = split_dataset(tensor_df, label_df)

# Scaling: Standardize features by removing the mean and scaling to unit variance.
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train) #mean and variance are calculated on the training dataset and applied to the training dataset
X_test_scaled = scaler.transform(X_test)       #mean and variance (previously calculated) are applied to the test dataset


print( len(tensor_df))
print( X_train.shape)
print( X_test.shape)
# Out:
# 61906
# (30953, 13)
# (30953, 13)

# %% [markdown]
# Subsequently we define the __model hyperparameters__, which influence the model ability to learn.
# <br><br>
# - The __learning rate__ is the model speed of the learning process: a too high learning rate can save some training time at the expenses of letting the model converge (i.e., minimizing the loss function); a small learning rate can significantly increase the training time and still fail to achieve an efficient minimum. By default, NNs are trained with a decreasing linear schedule, allowing for a constant decrease in the learning rate which helps the model converge.
# <br>
# - The __batch size__ is the number of samples to include in a single training iteration. The total number of batches can be obtained from: size of the training data/batch_size
# <br>
# - The number of __epochs__ is the number times that the learning algorithm will work through the entire training dataset
# <br>
# - Finally, setting the __verbose__ option equal to 1 allow us to obtain information on the training while in progress

# %%
# model hyperparameters
learning_rate1= 0.001  #the learning rate is the step size at each iteration while moving toward a minimum of a loss function
epochs = 1600          #An epoch in machine learning means one complete pass of the training dataset through the algorithm. 
batch_size = 8000      #the batch size is the number of training examples utilized in one iteration. A large batch size should make the training faster but may lead to memory saturation


verbose = 1
# Set the input shape
input_shape = X_train.shape[1]
print(f'Feature shape: {input_shape}')
# Out:
# Feature shape: 13

# %% [markdown]
# ### 4) Model training
#
# We create a simple model architecture given the small training dataset. In this case we construct a MLP model with two hidden layers. The first layer contains 10 perceptrons, while the second is made of 20 perceptrons. We use a sigmoid activation function (transfer function used in both hidden layers). Finally, we use the mean squared error (MSE) as loss function to be minimised and display the mean average error (MAE) for each training iteration (epoch).
# <br> By printing the model it is possible to observe the shape of each layer and the total number of weights to be updated with the training.

# %%
# training phase with the training dataset
def train():
    # here the network achitecture is defined: it is a feed forward neural network with 2 hidden layers, 
    # 20 perceptrons in the fisrt hidden layer and 10 in the second. Sigmoids are used as transfer function in both hidden layers.
    model = Sequential()
    model.add(Dense(20, input_dim=input_shape, kernel_initializer='normal', activation='sigmoid'))
    model.add(Dense(10, kernel_initializer='normal', activation='sigmoid')) ###second hidden
    model.add(Dense(1, kernel_initializer='normal', activation='linear')) #output
    model.summary()
    #the optimizer is the algorithm used for the training. Adam is a standard choice, but Scale conjugate gradient (SGD), is also very efficient.
    optimizer = optimizers.Adam(lr=learning_rate1)
    #optimizer = optimizers.experimental.SGD( learning_rate=learning_rate1)
    
    # here the model optimzer and the loss function to be minimized during training (mean squared error, MSE) are defined
    # the mean absolute error (mae) is also computed as additional metrics
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae']) 
    
    # the training dataset, the batch size and the number of epochs to be used re defined
    history = model.fit(
        X_train_scaled,
        y_train,
        batch_size=batch_size,
        epochs=epochs,
    # validation is also carried out
    # monitoring loss and metrics on the test dataset
    # at the end of each epoch
        validation_data=(X_test_scaled, y_test),)
    model.save('./mlp_model.h5') #the model is saved at the end of the training phase in an HFD5 output file
    return model, history

# %%
model, history = train()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                280
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 501
# Trainable params: 501
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1600
# 4/4 [==============================] - 1s 125ms/step - loss: 31.6243 - mae: 2.3660 - val_loss: 32.6058 - val_mae: 2.3504
# Epoch 2/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 31.4912 - mae: 2.3382 - val_loss: 32.4727 - val_mae: 2.3224
# Epoch 3/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 31.3580 - mae: 2.3103 - val_loss: 32.3392 - val_mae: 2.2950
# Epoch 4/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 31.2248 - mae: 2.2831 - val_loss: 32.2051 - val_mae: 2.2684
# Epoch 5/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 31.0895 - mae: 2.2568 - val_loss: 32.0703 - val_mae: 2.2428
# Epoch 6/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 30.9556 - mae: 2.2314 - val_loss: 31.9337 - val_mae: 2.2180
# Epoch 7/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 30.8180 - mae: 2.2069 - val_loss: 31.7953 - val_mae: 2.1941
# Epoch 8/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 30.6788 - mae: 2.1833 - val_loss: 31.6541 - val_mae: 2.1710
# Epoch 9/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 30.5368 - mae: 2.1604 - val_loss: 31.5096 - val_mae: 2.1489
# Epoch 10/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 30.3908 - mae: 2.1384 - val_loss: 31.3616 - val_mae: 2.1277
# Epoch 11/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 30.2424 - mae: 2.1176 - val_loss: 31.2097 - val_mae: 2.1074
# Epoch 12/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 30.0885 - mae: 2.0975 - val_loss: 31.0544 - val_mae: 2.0882
# Epoch 13/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 29.9323 - mae: 2.0787 - val_loss: 30.8954 - val_mae: 2.0700
# Epoch 14/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 29.7724 - mae: 2.0608 - val_loss: 30.7332 - val_mae: 2.0529
# Epoch 15/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 29.6100 - mae: 2.0439 - val_loss: 30.5681 - val_mae: 2.0369
# Epoch 16/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 29.4444 - mae: 2.0282 - val_loss: 30.4010 - val_mae: 2.0222
# Epoch 17/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 29.2764 - mae: 2.0138 - val_loss: 30.2328 - val_mae: 2.0086
# Epoch 18/1600
# 4/4 [==============================] - 0s 79ms/step - loss: 29.1090 - mae: 2.0007 - val_loss: 30.0637 - val_mae: 1.9962
# Epoch 19/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 28.9395 - mae: 1.9887 - val_loss: 29.8952 - val_mae: 1.9852
# Epoch 20/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 28.7718 - mae: 1.9781 - val_loss: 29.7276 - val_mae: 1.9755
# Epoch 21/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 28.6067 - mae: 1.9689 - val_loss: 29.5615 - val_mae: 1.9672
# Epoch 22/1600
# 4/4 [==============================] - 0s 39ms/step - loss: 28.4397 - mae: 1.9607 - val_loss: 29.3989 - val_mae: 1.9602
# Epoch 23/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 28.2790 - mae: 1.9540 - val_loss: 29.2393 - val_mae: 1.9545
# Epoch 24/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 28.1218 - mae: 1.9486 - val_loss: 29.0834 - val_mae: 1.9500
# Epoch 25/1600
# 4/4 [==============================] - 0s 76ms/step - loss: 27.9677 - mae: 1.9446 - val_loss: 28.9321 - val_mae: 1.9468
# Epoch 26/1600
# 4/4 [==============================] - 0s 20ms/step - loss: 27.8177 - mae: 1.9419 - val_loss: 28.7857 - val_mae: 1.9447
# Epoch 27/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 27.6732 - mae: 1.9401 - val_loss: 28.6446 - val_mae: 1.9439
# Epoch 28/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 27.5331 - mae: 1.9394 - val_loss: 28.5089 - val_mae: 1.9441
# Epoch 29/1600
# 4/4 [==============================] - 0s 75ms/step - loss: 27.4015 - mae: 1.9401 - val_loss: 28.3780 - val_mae: 1.9453
# Epoch 30/1600
# 4/4 [==============================] - 0s 65ms/step - loss: 27.2731 - mae: 1.9415 - val_loss: 28.2526 - val_mae: 1.9474
# Epoch 31/1600
# 4/4 [==============================] - 0s 47ms/step - loss: 27.1497 - mae: 1.9438 - val_loss: 28.1331 - val_mae: 1.9502
# Epoch 32/1600
# 4/4 [==============================] - 0s 62ms/step - loss: 27.0315 - mae: 1.9468 - val_loss: 28.0195 - val_mae: 1.9539
# Epoch 33/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 26.9207 - mae: 1.9506 - val_loss: 27.9108 - val_mae: 1.9582
# Epoch 34/1600
# 4/4 [==============================] - 0s 44ms/step - loss: 26.8139 - mae: 1.9550 - val_loss: 27.8077 - val_mae: 1.9631
# Epoch 35/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 26.7132 - mae: 1.9598 - val_loss: 27.7096 - val_mae: 1.9686
# Epoch 36/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 26.6176 - mae: 1.9652 - val_loss: 27.6164 - val_mae: 1.9745
# Epoch 37/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 26.5266 - mae: 1.9708 - val_loss: 27.5281 - val_mae: 1.9807
# Epoch 38/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 26.4399 - mae: 1.9770 - val_loss: 27.4445 - val_mae: 1.9872
# Epoch 39/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 26.3580 - mae: 1.9835 - val_loss: 27.3652 - val_mae: 1.9939
# Epoch 40/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 26.2802 - mae: 1.9900 - val_loss: 27.2900 - val_mae: 2.0008
# Epoch 41/1600
# 4/4 [==============================] - 0s 63ms/step - loss: 26.2074 - mae: 1.9967 - val_loss: 27.2185 - val_mae: 2.0077
# Epoch 42/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 26.1371 - mae: 2.0036 - val_loss: 27.1507 - val_mae: 2.0147
# Epoch 43/1600
# 4/4 [==============================] - 0s 19ms/step - loss: 26.0701 - mae: 2.0104 - val_loss: 27.0867 - val_mae: 2.0217
# Epoch 44/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 26.0079 - mae: 2.0173 - val_loss: 27.0254 - val_mae: 2.0286
# Epoch 45/1600
# 4/4 [==============================] - 0s 52ms/step - loss: 25.9485 - mae: 2.0243 - val_loss: 26.9670 - val_mae: 2.0356
# Epoch 46/1600
# 4/4 [==============================] - 0s 60ms/step - loss: 25.8905 - mae: 2.0311 - val_loss: 26.9116 - val_mae: 2.0423
# Epoch 47/1600
# 4/4 [==============================] - 0s 40ms/step - loss: 25.8360 - mae: 2.0378 - val_loss: 26.8589 - val_mae: 2.0489
# Epoch 48/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 25.7848 - mae: 2.0445 - val_loss: 26.8082 - val_mae: 2.0554
# Epoch 49/1600
# 4/4 [==============================] - 0s 60ms/step - loss: 25.7347 - mae: 2.0510 - val_loss: 26.7598 - val_mae: 2.0617
# Epoch 50/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 25.6876 - mae: 2.0575 - val_loss: 26.7133 - val_mae: 2.0678
# Epoch 51/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 25.6419 - mae: 2.0636 - val_loss: 26.6687 - val_mae: 2.0738
# Epoch 52/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 25.5989 - mae: 2.0697 - val_loss: 26.6256 - val_mae: 2.0797
# Epoch 53/1600
# 4/4 [==============================] - 0s 69ms/step - loss: 25.5559 - mae: 2.0756 - val_loss: 26.5845 - val_mae: 2.0853
# Epoch 54/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 25.5158 - mae: 2.0813 - val_loss: 26.5447 - val_mae: 2.0907
# Epoch 55/1600
# 4/4 [==============================] - 0s 40ms/step - loss: 25.4772 - mae: 2.0869 - val_loss: 26.5063 - val_mae: 2.0960
# Epoch 56/1600
# 4/4 [==============================] - 0s 69ms/step - loss: 25.4396 - mae: 2.0921 - val_loss: 26.4692 - val_mae: 2.1011
# Epoch 57/1600
# 4/4 [==============================] - 0s 60ms/step - loss: 25.4029 - mae: 2.0973 - val_loss: 26.4335 - val_mae: 2.1060
# Epoch 58/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 25.3679 - mae: 2.1022 - val_loss: 26.3989 - val_mae: 2.1107
# Epoch 59/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 25.3331 - mae: 2.1068 - val_loss: 26.3657 - val_mae: 2.1152
# Epoch 60/1600
# 4/4 [==============================] - 0s 40ms/step - loss: 25.3008 - mae: 2.1113 - val_loss: 26.3331 - val_mae: 2.1196
# Epoch 61/1600
# 4/4 [==============================] - 0s 40ms/step - loss: 25.2691 - mae: 2.1157 - val_loss: 26.3014 - val_mae: 2.1238
# Epoch 62/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 25.2386 - mae: 2.1201 - val_loss: 26.2703 - val_mae: 2.1280
# Epoch 63/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 25.2077 - mae: 2.1243 - val_loss: 26.2404 - val_mae: 2.1319
# Epoch 64/1600
# 4/4 [==============================] - 0s 62ms/step - loss: 25.1788 - mae: 2.1283 - val_loss: 26.2111 - val_mae: 2.1358
# Epoch 65/1600
# 4/4 [==============================] - 0s 40ms/step - loss: 25.1499 - mae: 2.1322 - val_loss: 26.1827 - val_mae: 2.1395
# Epoch 66/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 25.1217 - mae: 2.1358 - val_loss: 26.1552 - val_mae: 2.1429
# Epoch 67/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 25.0946 - mae: 2.1393 - val_loss: 26.1283 - val_mae: 2.1463
# Epoch 68/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 25.0689 - mae: 2.1429 - val_loss: 26.1017 - val_mae: 2.1497
# Epoch 69/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 25.0425 - mae: 2.1462 - val_loss: 26.0760 - val_mae: 2.1528
# Epoch 70/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 25.0173 - mae: 2.1494 - val_loss: 26.0509 - val_mae: 2.1559
# Epoch 71/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.9924 - mae: 2.1525 - val_loss: 26.0263 - val_mae: 2.1588
# Epoch 72/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 24.9687 - mae: 2.1555 - val_loss: 26.0022 - val_mae: 2.1617
# Epoch 73/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 24.9446 - mae: 2.1583 - val_loss: 25.9787 - val_mae: 2.1644
# Epoch 74/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.9220 - mae: 2.1611 - val_loss: 25.9555 - val_mae: 2.1672
# Epoch 75/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 24.8991 - mae: 2.1639 - val_loss: 25.9330 - val_mae: 2.1697
# Epoch 76/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 24.8769 - mae: 2.1665 - val_loss: 25.9108 - val_mae: 2.1722
# Epoch 77/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 24.8553 - mae: 2.1690 - val_loss: 25.8890 - val_mae: 2.1745
# Epoch 78/1600
# 4/4 [==============================] - 0s 40ms/step - loss: 24.8337 - mae: 2.1714 - val_loss: 25.8678 - val_mae: 2.1768
# Epoch 79/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 24.8131 - mae: 2.1737 - val_loss: 25.8468 - val_mae: 2.1791
# Epoch 80/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 24.7923 - mae: 2.1760 - val_loss: 25.8262 - val_mae: 2.1812
# Epoch 81/1600
# 4/4 [==============================] - 0s 55ms/step - loss: 24.7725 - mae: 2.1782 - val_loss: 25.8059 - val_mae: 2.1833
# Epoch 82/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 24.7530 - mae: 2.1805 - val_loss: 25.7860 - val_mae: 2.1854
# Epoch 83/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 24.7333 - mae: 2.1826 - val_loss: 25.7664 - val_mae: 2.1874
# Epoch 84/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 24.7138 - mae: 2.1845 - val_loss: 25.7473 - val_mae: 2.1892
# Epoch 85/1600
# 4/4 [==============================] - 0s 50ms/step - loss: 24.6953 - mae: 2.1864 - val_loss: 25.7284 - val_mae: 2.1910
# Epoch 86/1600
# 4/4 [==============================] - 0s 58ms/step - loss: 24.6767 - mae: 2.1882 - val_loss: 25.7099 - val_mae: 2.1927
# Epoch 87/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 24.6586 - mae: 2.1900 - val_loss: 25.6916 - val_mae: 2.1943
# Epoch 88/1600
# 4/4 [==============================] - 0s 58ms/step - loss: 24.6405 - mae: 2.1917 - val_loss: 25.6737 - val_mae: 2.1959
# Epoch 89/1600
# 4/4 [==============================] - 0s 39ms/step - loss: 24.6231 - mae: 2.1933 - val_loss: 25.6559 - val_mae: 2.1974
# Epoch 90/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 24.6059 - mae: 2.1949 - val_loss: 25.6384 - val_mae: 2.1990
# Epoch 91/1600
# 4/4 [==============================] - 0s 60ms/step - loss: 24.5883 - mae: 2.1965 - val_loss: 25.6212 - val_mae: 2.2004
# Epoch 92/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 24.5716 - mae: 2.1980 - val_loss: 25.6042 - val_mae: 2.2018
# Epoch 93/1600
# 4/4 [==============================] - 0s 62ms/step - loss: 24.5548 - mae: 2.1994 - val_loss: 25.5874 - val_mae: 2.2031
# Epoch 94/1600
# 4/4 [==============================] - 0s 40ms/step - loss: 24.5385 - mae: 2.2008 - val_loss: 25.5708 - val_mae: 2.2044
# Epoch 95/1600
# 4/4 [==============================] - 0s 62ms/step - loss: 24.5224 - mae: 2.2022 - val_loss: 25.5544 - val_mae: 2.2057
# Epoch 96/1600
# 4/4 [==============================] - 0s 50ms/step - loss: 24.5062 - mae: 2.2035 - val_loss: 25.5383 - val_mae: 2.2069
# Epoch 97/1600
# 4/4 [==============================] - 0s 39ms/step - loss: 24.4906 - mae: 2.2048 - val_loss: 25.5223 - val_mae: 2.2081
# Epoch 98/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 24.4748 - mae: 2.2061 - val_loss: 25.5065 - val_mae: 2.2093
# Epoch 99/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.4594 - mae: 2.2072 - val_loss: 25.4909 - val_mae: 2.2104
# Epoch 100/1600
# 4/4 [==============================] - 0s 62ms/step - loss: 24.4440 - mae: 2.2084 - val_loss: 25.4756 - val_mae: 2.2114
# Epoch 101/1600
# 4/4 [==============================] - 0s 71ms/step - loss: 24.4292 - mae: 2.2095 - val_loss: 25.4603 - val_mae: 2.2125
# Epoch 102/1600
# 4/4 [==============================] - 0s 55ms/step - loss: 24.4140 - mae: 2.2105 - val_loss: 25.4453 - val_mae: 2.2134
# Epoch 103/1600
# 4/4 [==============================] - 0s 25ms/step - loss: 24.3992 - mae: 2.2114 - val_loss: 25.4304 - val_mae: 2.2143
# Epoch 104/1600
# 4/4 [==============================] - 0s 71ms/step - loss: 24.3848 - mae: 2.2124 - val_loss: 25.4156 - val_mae: 2.2152
# Epoch 105/1600
# 4/4 [==============================] - 0s 78ms/step - loss: 24.3707 - mae: 2.2134 - val_loss: 25.4008 - val_mae: 2.2162
# Epoch 106/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.3560 - mae: 2.2143 - val_loss: 25.3864 - val_mae: 2.2170
# Epoch 107/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.3418 - mae: 2.2151 - val_loss: 25.3721 - val_mae: 2.2177
# Epoch 108/1600
# 4/4 [==============================] - 0s 60ms/step - loss: 24.3280 - mae: 2.2159 - val_loss: 25.3578 - val_mae: 2.2185
# Epoch 109/1600
# 4/4 [==============================] - 0s 40ms/step - loss: 24.3137 - mae: 2.2166 - val_loss: 25.3438 - val_mae: 2.2191
# Epoch 110/1600
# 4/4 [==============================] - 0s 62ms/step - loss: 24.3001 - mae: 2.2174 - val_loss: 25.3299 - val_mae: 2.2198
# Epoch 111/1600
# 4/4 [==============================] - 0s 60ms/step - loss: 24.2864 - mae: 2.2180 - val_loss: 25.3162 - val_mae: 2.2204
# Epoch 112/1600
# 4/4 [==============================] - 0s 39ms/step - loss: 24.2728 - mae: 2.2186 - val_loss: 25.3025 - val_mae: 2.2210
# Epoch 113/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 24.2598 - mae: 2.2193 - val_loss: 25.2888 - val_mae: 2.2216
# Epoch 114/1600
# 4/4 [==============================] - 0s 40ms/step - loss: 24.2460 - mae: 2.2198 - val_loss: 25.2755 - val_mae: 2.2221
# Epoch 115/1600
# 4/4 [==============================] - 0s 49ms/step - loss: 24.2332 - mae: 2.2204 - val_loss: 25.2620 - val_mae: 2.2227
# Epoch 116/1600
# 4/4 [==============================] - 0s 40ms/step - loss: 24.2201 - mae: 2.2210 - val_loss: 25.2487 - val_mae: 2.2231
# Epoch 117/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 24.2067 - mae: 2.2214 - val_loss: 25.2356 - val_mae: 2.2235
# Epoch 118/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 24.1943 - mae: 2.2218 - val_loss: 25.2224 - val_mae: 2.2240
# Epoch 119/1600
# 4/4 [==============================] - 0s 28ms/step - loss: 24.1812 - mae: 2.2223 - val_loss: 25.2094 - val_mae: 2.2243
# Epoch 120/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.1685 - mae: 2.2227 - val_loss: 25.1965 - val_mae: 2.2246
# Epoch 121/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 24.1560 - mae: 2.2230 - val_loss: 25.1836 - val_mae: 2.2250
# Epoch 122/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 24.1430 - mae: 2.2233 - val_loss: 25.1709 - val_mae: 2.2252
# Epoch 123/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.1304 - mae: 2.2235 - val_loss: 25.1583 - val_mae: 2.2253
# Epoch 124/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.1183 - mae: 2.2237 - val_loss: 25.1456 - val_mae: 2.2256
# Epoch 125/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.1055 - mae: 2.2239 - val_loss: 25.1331 - val_mae: 2.2257
# Epoch 126/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.0935 - mae: 2.2242 - val_loss: 25.1205 - val_mae: 2.2260
# Epoch 127/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 24.0812 - mae: 2.2245 - val_loss: 25.1080 - val_mae: 2.2262
# Epoch 128/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.0690 - mae: 2.2247 - val_loss: 25.0955 - val_mae: 2.2265
# Epoch 129/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.0567 - mae: 2.2249 - val_loss: 25.0831 - val_mae: 2.2266
# Epoch 130/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.0444 - mae: 2.2249 - val_loss: 25.0709 - val_mae: 2.2265
# Epoch 131/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.0322 - mae: 2.2249 - val_loss: 25.0587 - val_mae: 2.2265
# Epoch 132/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 24.0206 - mae: 2.2250 - val_loss: 25.0464 - val_mae: 2.2267
# Epoch 133/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 24.0082 - mae: 2.2250 - val_loss: 25.0342 - val_mae: 2.2266
# Epoch 134/1600
# 4/4 [==============================] - 0s 53ms/step - loss: 23.9964 - mae: 2.2250 - val_loss: 25.0220 - val_mae: 2.2266
# Epoch 135/1600
# 4/4 [==============================] - 0s 60ms/step - loss: 23.9845 - mae: 2.2251 - val_loss: 25.0099 - val_mae: 2.2266
# Epoch 136/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 23.9725 - mae: 2.2251 - val_loss: 24.9977 - val_mae: 2.2266
# Epoch 137/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.9607 - mae: 2.2250 - val_loss: 24.9856 - val_mae: 2.2265
# Epoch 138/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 23.9488 - mae: 2.2250 - val_loss: 24.9735 - val_mae: 2.2265
# Epoch 139/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 23.9368 - mae: 2.2249 - val_loss: 24.9615 - val_mae: 2.2263
# Epoch 140/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.9250 - mae: 2.2247 - val_loss: 24.9495 - val_mae: 2.2261
# Epoch 141/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 23.9131 - mae: 2.2245 - val_loss: 24.9375 - val_mae: 2.2259
# Epoch 142/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.9013 - mae: 2.2242 - val_loss: 24.9255 - val_mae: 2.2256
# Epoch 143/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 23.8893 - mae: 2.2239 - val_loss: 24.9135 - val_mae: 2.2252
# Epoch 144/1600
# 4/4 [==============================] - 0s 58ms/step - loss: 23.8776 - mae: 2.2236 - val_loss: 24.9015 - val_mae: 2.2249
# Epoch 145/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.8658 - mae: 2.2234 - val_loss: 24.8895 - val_mae: 2.2247
# Epoch 146/1600
# 4/4 [==============================] - 0s 63ms/step - loss: 23.8540 - mae: 2.2231 - val_loss: 24.8775 - val_mae: 2.2244
# Epoch 147/1600
# 4/4 [==============================] - 0s 40ms/step - loss: 23.8418 - mae: 2.2227 - val_loss: 24.8655 - val_mae: 2.2238
# Epoch 148/1600
# 4/4 [==============================] - 0s 18ms/step - loss: 23.8304 - mae: 2.2223 - val_loss: 24.8534 - val_mae: 2.2236
# Epoch 149/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 23.8182 - mae: 2.2219 - val_loss: 24.8414 - val_mae: 2.2231
# Epoch 150/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 23.8064 - mae: 2.2215 - val_loss: 24.8294 - val_mae: 2.2227
# Epoch 151/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 23.7947 - mae: 2.2212 - val_loss: 24.8172 - val_mae: 2.2225
# Epoch 152/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 23.7824 - mae: 2.2208 - val_loss: 24.8051 - val_mae: 2.2219
# Epoch 153/1600
# 4/4 [==============================] - 0s 60ms/step - loss: 23.7706 - mae: 2.2203 - val_loss: 24.7930 - val_mae: 2.2214
# Epoch 154/1600
# 4/4 [==============================] - 0s 60ms/step - loss: 23.7587 - mae: 2.2199 - val_loss: 24.7807 - val_mae: 2.2211
# Epoch 155/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 23.7464 - mae: 2.2194 - val_loss: 24.7686 - val_mae: 2.2204
# Epoch 156/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 23.7346 - mae: 2.2189 - val_loss: 24.7563 - val_mae: 2.2200
# Epoch 157/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 23.7223 - mae: 2.2183 - val_loss: 24.7440 - val_mae: 2.2194
# Epoch 158/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 23.7099 - mae: 2.2176 - val_loss: 24.7317 - val_mae: 2.2186
# Epoch 159/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 23.6977 - mae: 2.2168 - val_loss: 24.7194 - val_mae: 2.2178
# Epoch 160/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 23.6855 - mae: 2.2161 - val_loss: 24.7070 - val_mae: 2.2171
# Epoch 161/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 23.6730 - mae: 2.2153 - val_loss: 24.6946 - val_mae: 2.2163
# Epoch 162/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 23.6607 - mae: 2.2146 - val_loss: 24.6820 - val_mae: 2.2157
# Epoch 163/1600
# 4/4 [==============================] - 0s 15ms/step - loss: 23.6484 - mae: 2.2140 - val_loss: 24.6693 - val_mae: 2.2151
# Epoch 164/1600
# 4/4 [==============================] - 0s 41ms/step - loss: 23.6360 - mae: 2.2136 - val_loss: 24.6565 - val_mae: 2.2146
# Epoch 165/1600
# 4/4 [==============================] - 0s 58ms/step - loss: 23.6230 - mae: 2.2129 - val_loss: 24.6438 - val_mae: 2.2139
# Epoch 166/1600
# 4/4 [==============================] - 0s 41ms/step - loss: 23.6104 - mae: 2.2123 - val_loss: 24.6309 - val_mae: 2.2132
# Epoch 167/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.5974 - mae: 2.2114 - val_loss: 24.6180 - val_mae: 2.2123
# Epoch 168/1600
# 4/4 [==============================] - 0s 40ms/step - loss: 23.5848 - mae: 2.2106 - val_loss: 24.6050 - val_mae: 2.2115
# Epoch 169/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 23.5715 - mae: 2.2097 - val_loss: 24.5920 - val_mae: 2.2105
# Epoch 170/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.5587 - mae: 2.2089 - val_loss: 24.5787 - val_mae: 2.2098
# Epoch 171/1600
# 4/4 [==============================] - 0s 28ms/step - loss: 23.5455 - mae: 2.2081 - val_loss: 24.5654 - val_mae: 2.2090
# Epoch 172/1600
# 4/4 [==============================] - 0s 66ms/step - loss: 23.5320 - mae: 2.2072 - val_loss: 24.5521 - val_mae: 2.2081
# Epoch 173/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.5188 - mae: 2.2063 - val_loss: 24.5386 - val_mae: 2.2072
# Epoch 174/1600
# 4/4 [==============================] - 0s 62ms/step - loss: 23.5054 - mae: 2.2054 - val_loss: 24.5250 - val_mae: 2.2063
# Epoch 175/1600
# 4/4 [==============================] - 0s 50ms/step - loss: 23.4918 - mae: 2.2045 - val_loss: 24.5113 - val_mae: 2.2053
# Epoch 176/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 23.4779 - mae: 2.2035 - val_loss: 24.4976 - val_mae: 2.2043
# Epoch 177/1600
# 4/4 [==============================] - 0s 66ms/step - loss: 23.4644 - mae: 2.2025 - val_loss: 24.4837 - val_mae: 2.2034
# Epoch 178/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 23.4503 - mae: 2.2015 - val_loss: 24.4697 - val_mae: 2.2024
# Epoch 179/1600
# 4/4 [==============================] - 0s 60ms/step - loss: 23.4364 - mae: 2.2005 - val_loss: 24.4556 - val_mae: 2.2014
# Epoch 180/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.4226 - mae: 2.1997 - val_loss: 24.4413 - val_mae: 2.2006
# Epoch 181/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.4076 - mae: 2.1984 - val_loss: 24.4272 - val_mae: 2.1991
# Epoch 182/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.3939 - mae: 2.1973 - val_loss: 24.4127 - val_mae: 2.1982
# Epoch 183/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 23.3790 - mae: 2.1961 - val_loss: 24.3983 - val_mae: 2.1969
# Epoch 184/1600
# 4/4 [==============================] - 0s 60ms/step - loss: 23.3645 - mae: 2.1949 - val_loss: 24.3836 - val_mae: 2.1958
# Epoch 185/1600
# 4/4 [==============================] - 0s 39ms/step - loss: 23.3499 - mae: 2.1938 - val_loss: 24.3689 - val_mae: 2.1947
# Epoch 186/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 23.3351 - mae: 2.1927 - val_loss: 24.3540 - val_mae: 2.1937
# Epoch 187/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.3200 - mae: 2.1916 - val_loss: 24.3390 - val_mae: 2.1926
# Epoch 188/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.3050 - mae: 2.1905 - val_loss: 24.3239 - val_mae: 2.1914
# Epoch 189/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 23.2900 - mae: 2.1894 - val_loss: 24.3087 - val_mae: 2.1903
# Epoch 190/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.2743 - mae: 2.1882 - val_loss: 24.2934 - val_mae: 2.1891
# Epoch 191/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 23.2591 - mae: 2.1870 - val_loss: 24.2780 - val_mae: 2.1879
# Epoch 192/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 23.2433 - mae: 2.1856 - val_loss: 24.2625 - val_mae: 2.1865
# Epoch 193/1600
# 4/4 [==============================] - 0s 39ms/step - loss: 23.2279 - mae: 2.1843 - val_loss: 24.2468 - val_mae: 2.1854
# Epoch 194/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 23.2120 - mae: 2.1831 - val_loss: 24.2311 - val_mae: 2.1841
# Epoch 195/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 23.1960 - mae: 2.1817 - val_loss: 24.2153 - val_mae: 2.1827
# Epoch 196/1600
# 4/4 [==============================] - 0s 41ms/step - loss: 23.1799 - mae: 2.1802 - val_loss: 24.1995 - val_mae: 2.1813
# Epoch 197/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.1640 - mae: 2.1789 - val_loss: 24.1834 - val_mae: 2.1801
# Epoch 198/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 23.1480 - mae: 2.1777 - val_loss: 24.1672 - val_mae: 2.1789
# Epoch 199/1600
# 4/4 [==============================] - 0s 77ms/step - loss: 23.1315 - mae: 2.1765 - val_loss: 24.1511 - val_mae: 2.1777
# Epoch 200/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.1151 - mae: 2.1751 - val_loss: 24.1348 - val_mae: 2.1762
# Epoch 201/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.0987 - mae: 2.1736 - val_loss: 24.1185 - val_mae: 2.1748
# Epoch 202/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.0822 - mae: 2.1723 - val_loss: 24.1021 - val_mae: 2.1735
# Epoch 203/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 23.0657 - mae: 2.1710 - val_loss: 24.0855 - val_mae: 2.1723
# Epoch 204/1600
# 4/4 [==============================] - 0s 50ms/step - loss: 23.0490 - mae: 2.1697 - val_loss: 24.0689 - val_mae: 2.1709
# Epoch 205/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.0323 - mae: 2.1684 - val_loss: 24.0523 - val_mae: 2.1697
# Epoch 206/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 23.0157 - mae: 2.1672 - val_loss: 24.0355 - val_mae: 2.1687
# Epoch 207/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.9985 - mae: 2.1659 - val_loss: 24.0188 - val_mae: 2.1671
# Epoch 208/1600
# 4/4 [==============================] - 0s 60ms/step - loss: 22.9814 - mae: 2.1643 - val_loss: 24.0021 - val_mae: 2.1655
# Epoch 209/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 22.9646 - mae: 2.1628 - val_loss: 23.9853 - val_mae: 2.1643
# Epoch 210/1600
# 4/4 [==============================] - 0s 62ms/step - loss: 22.9479 - mae: 2.1617 - val_loss: 23.9683 - val_mae: 2.1632
# Epoch 211/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 22.9306 - mae: 2.1603 - val_loss: 23.9514 - val_mae: 2.1619
# Epoch 212/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 22.9132 - mae: 2.1588 - val_loss: 23.9345 - val_mae: 2.1603
# Epoch 213/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 22.8966 - mae: 2.1574 - val_loss: 23.9174 - val_mae: 2.1592
# Epoch 214/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 22.8793 - mae: 2.1563 - val_loss: 23.9004 - val_mae: 2.1580
# Epoch 215/1600
# 4/4 [==============================] - 0s 60ms/step - loss: 22.8620 - mae: 2.1550 - val_loss: 23.8834 - val_mae: 2.1568
# Epoch 216/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 22.8450 - mae: 2.1538 - val_loss: 23.8663 - val_mae: 2.1556
# Epoch 217/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 22.8280 - mae: 2.1527 - val_loss: 23.8492 - val_mae: 2.1546
# Epoch 218/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 22.8107 - mae: 2.1516 - val_loss: 23.8321 - val_mae: 2.1535
# Epoch 219/1600
# 4/4 [==============================] - 0s 39ms/step - loss: 22.7932 - mae: 2.1502 - val_loss: 23.8151 - val_mae: 2.1520
# Epoch 220/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 22.7761 - mae: 2.1486 - val_loss: 23.7980 - val_mae: 2.1504
# Epoch 221/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.7591 - mae: 2.1473 - val_loss: 23.7809 - val_mae: 2.1493
# Epoch 222/1600
# 4/4 [==============================] - 0s 40ms/step - loss: 22.7420 - mae: 2.1461 - val_loss: 23.7638 - val_mae: 2.1481
# Epoch 223/1600
# 4/4 [==============================] - 0s 58ms/step - loss: 22.7242 - mae: 2.1446 - val_loss: 23.7469 - val_mae: 2.1464
# Epoch 224/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 22.7072 - mae: 2.1430 - val_loss: 23.7299 - val_mae: 2.1450
# Epoch 225/1600
# 4/4 [==============================] - 0s 60ms/step - loss: 22.6902 - mae: 2.1415 - val_loss: 23.7128 - val_mae: 2.1437
# Epoch 226/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 22.6733 - mae: 2.1404 - val_loss: 23.6956 - val_mae: 2.1427
# Epoch 227/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 22.6558 - mae: 2.1390 - val_loss: 23.6786 - val_mae: 2.1411
# Epoch 228/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 22.6386 - mae: 2.1374 - val_loss: 23.6616 - val_mae: 2.1398
# Epoch 229/1600
# 4/4 [==============================] - 0s 17ms/step - loss: 22.6217 - mae: 2.1362 - val_loss: 23.6446 - val_mae: 2.1387
# Epoch 230/1600
# 4/4 [==============================] - 0s 60ms/step - loss: 22.6043 - mae: 2.1349 - val_loss: 23.6276 - val_mae: 2.1373
# Epoch 231/1600
# 4/4 [==============================] - 0s 61ms/step - loss: 22.5872 - mae: 2.1334 - val_loss: 23.6107 - val_mae: 2.1359
# Epoch 232/1600
# 4/4 [==============================] - 0s 39ms/step - loss: 22.5700 - mae: 2.1319 - val_loss: 23.5938 - val_mae: 2.1345
# Epoch 233/1600
# 4/4 [==============================] - 0s 16ms/step - loss: 22.5532 - mae: 2.1306 - val_loss: 23.5768 - val_mae: 2.1334
# Epoch 234/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 22.5362 - mae: 2.1294 - val_loss: 23.5598 - val_mae: 2.1323
# Epoch 235/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 22.5189 - mae: 2.1281 - val_loss: 23.5428 - val_mae: 2.1308
# Epoch 236/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 22.5021 - mae: 2.1266 - val_loss: 23.5258 - val_mae: 2.1295
# Epoch 237/1600
# 4/4 [==============================] - 0s 37ms/step - loss: 22.4847 - mae: 2.1250 - val_loss: 23.5089 - val_mae: 2.1280
# Epoch 238/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 22.4678 - mae: 2.1236 - val_loss: 23.4920 - val_mae: 2.1265
# Epoch 239/1600
# 4/4 [==============================] - 0s 38ms/step - loss: 22.4509 - mae: 2.1221 - val_loss: 23.4749 - val_mae: 2.1252
# Epoch 240/1600
# 4/4 [==============================] - 0s 59ms/step - loss: 22.4335 - mae: 2.1206 - val_loss: 23.4580 - val_mae: 2.1238
# Epoch 241/1600
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_167308\3370585772.py in <module>
# ----> 1 model, history = train()
#
# ~\AppData\Local\Temp\ipykernel_167308\3614462226.py in train()
#      17
#      18     # the training dataset, the batch size and the number of epochs to be used re defined
# ---> 19     history = model.fit(
#      20         X_train_scaled,
#      21         y_train,
#
# ~\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ### 5) Model evaluation
#
# Here we plot the learning curves, i.e., the MAE obtained ad each iteration (epoch) as a function of the epoch number. By observing the learning curves, we clearly see that the training and test values of the loss function decrease with the number of epochs. However, the decreasing rate of the two curves slows down, and the two curves become almost flat somewhat near the 1400th epoch, which means that the training of the model is almost completed. Moreover, the two (train and test) loss curves are very similar to each other, this is a clear sign of the generalizability of the model. In other terms, if we train on a dataset and we get the same result on an indipendent test dataset (with different observations) we expect that the application of the model to any other dataset will still give the same accuracy (i.e., validation dataset which is not considered in this exercise).
# <br> Overall, it is possible to observe that the two curves do not fully reach and asymptotic value, and it may be possible that a further training of the model brigns to slightly better results.

# %%
import matplotlib.pyplot as plt
# plot learning curves
plt.title('Learning Curves')
plt.xlabel('Epoch')
plt.ylabel('MSE loss')
plt.plot((history.history['loss']), label='train')
plt.plot((history.history['val_loss']), label='test')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_167308\265850228.py in <module>
#       4 plt.xlabel('Epoch')
#       5 plt.ylabel('MSE loss')
# ----> 6 plt.plot((history.history['loss']), label='train')
#       7 plt.plot((history.history['val_loss']), label='test')
#       8 plt.legend()
#
# NameError: name 'history' is not defined

# %% [markdown]
# ### 6) Further training of the model and overfitting
#
# The model can be further trained for even more Epochs, but it will be subject to overfitting. An overfitting model reproduces too closely the target variable in a specific training dataset, and may therefore fail to fit additional data or predict future observations reliably.  In other words, the model memorizes the training dataset too well, learning also the noise included, and it is not able to generalise any more. <br>The following code loads the model that has been trained in section 6 and trains it further for additional 1000 epochs, using the same training hyperparameters (learning rate, batch size, etc.).

# %%
# training phase with the training dataset
fine_tune_epochs = 1000
total_epochs =  epochs + fine_tune_epochs
def train_fine(model):

    optimizer = optimizers.Adam(lr=learning_rate1)
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
    history_fine = model.fit(
        X_train_scaled,
        y_train,
        batch_size=batch_size,
        epochs=total_epochs,
        initial_epoch=history.epoch[-1],
    # We also carry out some validation to
    # monitor loss and metrics on the test dataset
    # at the end of each epoch
        validation_data=(X_test_scaled, y_test),)
        #validation_data=(X_test, np.log10(y_test)),)
    model.save('./mlp_model_1.h5')
    return model, history_fine
new_model = tf.keras.models.load_model('./mlp_model.h5')
model_fine, history_fine = train_fine(new_model)
# Out:
# Epoch 1600/2600
# 4/4 [==============================] - 1s 146ms/step - loss: 12.8872 - mae: 1.4556 - val_loss: 13.2455 - val_mae: 1.4574
# Epoch 1601/2600
# 4/4 [==============================] - 0s 41ms/step - loss: 12.8681 - mae: 1.4501 - val_loss: 13.2492 - val_mae: 1.4520
# Epoch 1602/2600
# 4/4 [==============================] - 0s 38ms/step - loss: 12.8684 - mae: 1.4505 - val_loss: 13.2438 - val_mae: 1.4579
# Epoch 1603/2600
# 4/4 [==============================] - 0s 59ms/step - loss: 12.8649 - mae: 1.4550 - val_loss: 13.2404 - val_mae: 1.4593
# Epoch 1604/2600
# 4/4 [==============================] - 0s 40ms/step - loss: 12.8624 - mae: 1.4533 - val_loss: 13.2421 - val_mae: 1.4556
# Epoch 1605/2600
# 4/4 [==============================] - 0s 40ms/step - loss: 12.8633 - mae: 1.4536 - val_loss: 13.2404 - val_mae: 1.4581
# Epoch 1606/2600
# 4/4 [==============================] - 0s 39ms/step - loss: 12.8603 - mae: 1.4519 - val_loss: 13.2396 - val_mae: 1.4549
# Epoch 1607/2600
# 4/4 [==============================] - 0s 71ms/step - loss: 12.8614 - mae: 1.4493 - val_loss: 13.2395 - val_mae: 1.4544
# Epoch 1608/2600
# 4/4 [==============================] - 0s 77ms/step - loss: 12.8561 - mae: 1.4522 - val_loss: 13.2326 - val_mae: 1.4596
# Epoch 1609/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.8547 - mae: 1.4558 - val_loss: 13.2300 - val_mae: 1.4587
# Epoch 1610/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.8520 - mae: 1.4540 - val_loss: 13.2280 - val_mae: 1.4575
# Epoch 1611/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.8485 - mae: 1.4517 - val_loss: 13.2269 - val_mae: 1.4538
# Epoch 1612/2600
# 4/4 [==============================] - 0s 16ms/step - loss: 12.8481 - mae: 1.4490 - val_loss: 13.2248 - val_mae: 1.4529
# Epoch 1613/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.8494 - mae: 1.4511 - val_loss: 13.2218 - val_mae: 1.4562
# Epoch 1614/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.8481 - mae: 1.4543 - val_loss: 13.2188 - val_mae: 1.4596
# Epoch 1615/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.8414 - mae: 1.4538 - val_loss: 13.2188 - val_mae: 1.4554
# Epoch 1616/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.8399 - mae: 1.4513 - val_loss: 13.2181 - val_mae: 1.4548
# Epoch 1617/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.8381 - mae: 1.4512 - val_loss: 13.2140 - val_mae: 1.4561
# Epoch 1618/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.8393 - mae: 1.4513 - val_loss: 13.2111 - val_mae: 1.4561
# Epoch 1619/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.8353 - mae: 1.4529 - val_loss: 13.2079 - val_mae: 1.4586
# Epoch 1620/2600
# 4/4 [==============================] - 0s 85ms/step - loss: 12.8325 - mae: 1.4547 - val_loss: 13.2068 - val_mae: 1.4587
# Epoch 1621/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.8313 - mae: 1.4538 - val_loss: 13.2071 - val_mae: 1.4556
# Epoch 1622/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.8294 - mae: 1.4511 - val_loss: 13.2064 - val_mae: 1.4534
# Epoch 1623/2600
# 4/4 [==============================] - 0s 86ms/step - loss: 12.8283 - mae: 1.4490 - val_loss: 13.2030 - val_mae: 1.4527
# Epoch 1624/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.8279 - mae: 1.4505 - val_loss: 13.1961 - val_mae: 1.4564
# Epoch 1625/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.8247 - mae: 1.4516 - val_loss: 13.1967 - val_mae: 1.4551
# Epoch 1626/2600
# 4/4 [==============================] - 0s 86ms/step - loss: 12.8223 - mae: 1.4513 - val_loss: 13.1948 - val_mae: 1.4566
# Epoch 1627/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.8206 - mae: 1.4531 - val_loss: 13.1937 - val_mae: 1.4574
# Epoch 1628/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.8199 - mae: 1.4541 - val_loss: 13.1926 - val_mae: 1.4573
# Epoch 1629/2600
# 4/4 [==============================] - 0s 86ms/step - loss: 12.8173 - mae: 1.4515 - val_loss: 13.1925 - val_mae: 1.4533
# Epoch 1630/2600
# 4/4 [==============================] - 0s 85ms/step - loss: 12.8167 - mae: 1.4496 - val_loss: 13.1897 - val_mae: 1.4537
# Epoch 1631/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.8131 - mae: 1.4501 - val_loss: 13.1857 - val_mae: 1.4546
# Epoch 1632/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.8120 - mae: 1.4515 - val_loss: 13.1826 - val_mae: 1.4555
# Epoch 1633/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.8105 - mae: 1.4511 - val_loss: 13.1831 - val_mae: 1.4542
# Epoch 1634/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.8083 - mae: 1.4509 - val_loss: 13.1804 - val_mae: 1.4562
# Epoch 1635/2600
# 4/4 [==============================] - 0s 85ms/step - loss: 12.8111 - mae: 1.4541 - val_loss: 13.1743 - val_mae: 1.4576
# Epoch 1636/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.8068 - mae: 1.4526 - val_loss: 13.1735 - val_mae: 1.4550
# Epoch 1637/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.8100 - mae: 1.4531 - val_loss: 13.1750 - val_mae: 1.4555
# Epoch 1638/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.8023 - mae: 1.4487 - val_loss: 13.1806 - val_mae: 1.4492
# Epoch 1639/2600
# 4/4 [==============================] - 0s 99ms/step - loss: 12.8028 - mae: 1.4461 - val_loss: 13.1765 - val_mae: 1.4519
# Epoch 1640/2600
# 4/4 [==============================] - 0s 85ms/step - loss: 12.8006 - mae: 1.4498 - val_loss: 13.1707 - val_mae: 1.4563
# Epoch 1641/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7979 - mae: 1.4520 - val_loss: 13.1670 - val_mae: 1.4548
# Epoch 1642/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7966 - mae: 1.4499 - val_loss: 13.1665 - val_mae: 1.4534
# Epoch 1643/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.7941 - mae: 1.4516 - val_loss: 13.1608 - val_mae: 1.4572
# Epoch 1644/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7919 - mae: 1.4538 - val_loss: 13.1600 - val_mae: 1.4584
# Epoch 1645/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7918 - mae: 1.4551 - val_loss: 13.1583 - val_mae: 1.4582
# Epoch 1646/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7913 - mae: 1.4524 - val_loss: 13.1586 - val_mae: 1.4542
# Epoch 1647/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7861 - mae: 1.4490 - val_loss: 13.1600 - val_mae: 1.4498
# Epoch 1648/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7880 - mae: 1.4457 - val_loss: 13.1603 - val_mae: 1.4496
# Epoch 1649/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7834 - mae: 1.4486 - val_loss: 13.1532 - val_mae: 1.4557
# Epoch 1650/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7817 - mae: 1.4530 - val_loss: 13.1498 - val_mae: 1.4581
# Epoch 1651/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.7838 - mae: 1.4533 - val_loss: 13.1472 - val_mae: 1.4569
# Epoch 1652/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7803 - mae: 1.4518 - val_loss: 13.1445 - val_mae: 1.4533
# Epoch 1653/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7809 - mae: 1.4481 - val_loss: 13.1458 - val_mae: 1.4508
# Epoch 1654/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.7758 - mae: 1.4491 - val_loss: 13.1398 - val_mae: 1.4550
# Epoch 1655/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7742 - mae: 1.4520 - val_loss: 13.1376 - val_mae: 1.4574
# Epoch 1656/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7742 - mae: 1.4539 - val_loss: 13.1366 - val_mae: 1.4568
# Epoch 1657/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7737 - mae: 1.4506 - val_loss: 13.1389 - val_mae: 1.4512
# Epoch 1658/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.7710 - mae: 1.4471 - val_loss: 13.1375 - val_mae: 1.4513
# Epoch 1659/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.7683 - mae: 1.4496 - val_loss: 13.1330 - val_mae: 1.4556
# Epoch 1660/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.7697 - mae: 1.4530 - val_loss: 13.1295 - val_mae: 1.4556
# Epoch 1661/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.7647 - mae: 1.4516 - val_loss: 13.1284 - val_mae: 1.4548
# Epoch 1662/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.7674 - mae: 1.4492 - val_loss: 13.1293 - val_mae: 1.4511
# Epoch 1663/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.7627 - mae: 1.4481 - val_loss: 13.1270 - val_mae: 1.4536
# Epoch 1664/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.7596 - mae: 1.4506 - val_loss: 13.1279 - val_mae: 1.4566
# Epoch 1665/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7609 - mae: 1.4531 - val_loss: 13.1258 - val_mae: 1.4565
# Epoch 1666/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7599 - mae: 1.4527 - val_loss: 13.1216 - val_mae: 1.4540
# Epoch 1667/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7561 - mae: 1.4488 - val_loss: 13.1259 - val_mae: 1.4506
# Epoch 1668/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.7595 - mae: 1.4456 - val_loss: 13.1263 - val_mae: 1.4489
# Epoch 1669/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7533 - mae: 1.4476 - val_loss: 13.1199 - val_mae: 1.4547
# Epoch 1670/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7518 - mae: 1.4532 - val_loss: 13.1197 - val_mae: 1.4594
# Epoch 1671/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7556 - mae: 1.4547 - val_loss: 13.1169 - val_mae: 1.4555
# Epoch 1672/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7479 - mae: 1.4515 - val_loss: 13.1147 - val_mae: 1.4539
# Epoch 1673/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7479 - mae: 1.4488 - val_loss: 13.1152 - val_mae: 1.4512
# Epoch 1674/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.7477 - mae: 1.4495 - val_loss: 13.1093 - val_mae: 1.4546
# Epoch 1675/2600
# 4/4 [==============================] - 0s 85ms/step - loss: 12.7466 - mae: 1.4511 - val_loss: 13.1080 - val_mae: 1.4547
# Epoch 1676/2600
# 4/4 [==============================] - 1s 184ms/step - loss: 12.7424 - mae: 1.4498 - val_loss: 13.1060 - val_mae: 1.4508
# Epoch 1677/2600
# 4/4 [==============================] - 0s 87ms/step - loss: 12.7415 - mae: 1.4469 - val_loss: 13.1066 - val_mae: 1.4497
# Epoch 1678/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.7442 - mae: 1.4476 - val_loss: 13.1040 - val_mae: 1.4533
# Epoch 1679/2600
# 4/4 [==============================] - 0s 86ms/step - loss: 12.7429 - mae: 1.4515 - val_loss: 13.0984 - val_mae: 1.4541
# Epoch 1680/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7368 - mae: 1.4504 - val_loss: 13.1007 - val_mae: 1.4521
# Epoch 1681/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.7365 - mae: 1.4496 - val_loss: 13.0980 - val_mae: 1.4532
# Epoch 1682/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.7342 - mae: 1.4487 - val_loss: 13.0997 - val_mae: 1.4510
# Epoch 1683/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.7344 - mae: 1.4481 - val_loss: 13.0994 - val_mae: 1.4520
# Epoch 1684/2600
# 4/4 [==============================] - 0s 86ms/step - loss: 12.7317 - mae: 1.4487 - val_loss: 13.0945 - val_mae: 1.4533
# Epoch 1685/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.7308 - mae: 1.4500 - val_loss: 13.0915 - val_mae: 1.4535
# Epoch 1686/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7286 - mae: 1.4509 - val_loss: 13.0901 - val_mae: 1.4540
# Epoch 1687/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7289 - mae: 1.4497 - val_loss: 13.0929 - val_mae: 1.4529
# Epoch 1688/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7263 - mae: 1.4485 - val_loss: 13.0920 - val_mae: 1.4525
# Epoch 1689/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7290 - mae: 1.4517 - val_loss: 13.0868 - val_mae: 1.4561
# Epoch 1690/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7267 - mae: 1.4525 - val_loss: 13.0873 - val_mae: 1.4541
# Epoch 1691/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7201 - mae: 1.4491 - val_loss: 13.0875 - val_mae: 1.4500
# Epoch 1692/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7198 - mae: 1.4462 - val_loss: 13.0868 - val_mae: 1.4487
# Epoch 1693/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7250 - mae: 1.4451 - val_loss: 13.0847 - val_mae: 1.4490
# Epoch 1694/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7159 - mae: 1.4483 - val_loss: 13.0775 - val_mae: 1.4563
# Epoch 1695/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7167 - mae: 1.4530 - val_loss: 13.0768 - val_mae: 1.4575
# Epoch 1696/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.7169 - mae: 1.4539 - val_loss: 13.0751 - val_mae: 1.4562
# Epoch 1697/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7147 - mae: 1.4506 - val_loss: 13.0741 - val_mae: 1.4500
# Epoch 1698/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7124 - mae: 1.4461 - val_loss: 13.0746 - val_mae: 1.4489
# Epoch 1699/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7111 - mae: 1.4473 - val_loss: 13.0719 - val_mae: 1.4516
# Epoch 1700/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7131 - mae: 1.4503 - val_loss: 13.0683 - val_mae: 1.4550
# Epoch 1701/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7088 - mae: 1.4500 - val_loss: 13.0725 - val_mae: 1.4511
# Epoch 1702/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7068 - mae: 1.4470 - val_loss: 13.0708 - val_mae: 1.4493
# Epoch 1703/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7075 - mae: 1.4476 - val_loss: 13.0662 - val_mae: 1.4526
# Epoch 1704/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.7043 - mae: 1.4489 - val_loss: 13.0668 - val_mae: 1.4520
# Epoch 1705/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.7038 - mae: 1.4474 - val_loss: 13.0690 - val_mae: 1.4491
# Epoch 1706/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7012 - mae: 1.4464 - val_loss: 13.0644 - val_mae: 1.4518
# Epoch 1707/2600
# 4/4 [==============================] - 0s 78ms/step - loss: 12.7004 - mae: 1.4501 - val_loss: 13.0602 - val_mae: 1.4546
# Epoch 1708/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.7014 - mae: 1.4506 - val_loss: 13.0609 - val_mae: 1.4543
# Epoch 1709/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.7023 - mae: 1.4527 - val_loss: 13.0553 - val_mae: 1.4555
# Epoch 1710/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6955 - mae: 1.4496 - val_loss: 13.0596 - val_mae: 1.4481
# Epoch 1711/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.7099 - mae: 1.4424 - val_loss: 13.0658 - val_mae: 1.4455
# Epoch 1712/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6931 - mae: 1.4453 - val_loss: 13.0534 - val_mae: 1.4552
# Epoch 1713/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6987 - mae: 1.4550 - val_loss: 13.0556 - val_mae: 1.4605
# Epoch 1714/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6940 - mae: 1.4550 - val_loss: 13.0495 - val_mae: 1.4530
# Epoch 1715/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6965 - mae: 1.4457 - val_loss: 13.0621 - val_mae: 1.4444
# Epoch 1716/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6965 - mae: 1.4436 - val_loss: 13.0484 - val_mae: 1.4507
# Epoch 1717/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6865 - mae: 1.4476 - val_loss: 13.0464 - val_mae: 1.4530
# Epoch 1718/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6867 - mae: 1.4500 - val_loss: 13.0481 - val_mae: 1.4540
# Epoch 1719/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6880 - mae: 1.4525 - val_loss: 13.0447 - val_mae: 1.4560
# Epoch 1720/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6844 - mae: 1.4523 - val_loss: 13.0432 - val_mae: 1.4521
# Epoch 1721/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6913 - mae: 1.4459 - val_loss: 13.0542 - val_mae: 1.4458
# Epoch 1722/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6891 - mae: 1.4448 - val_loss: 13.0439 - val_mae: 1.4513
# Epoch 1723/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6801 - mae: 1.4495 - val_loss: 13.0374 - val_mae: 1.4548
# Epoch 1724/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6812 - mae: 1.4510 - val_loss: 13.0374 - val_mae: 1.4539
# Epoch 1725/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6789 - mae: 1.4513 - val_loss: 13.0353 - val_mae: 1.4534
# Epoch 1726/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6786 - mae: 1.4480 - val_loss: 13.0407 - val_mae: 1.4489
# Epoch 1727/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6793 - mae: 1.4454 - val_loss: 13.0360 - val_mae: 1.4495
# Epoch 1728/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6754 - mae: 1.4472 - val_loss: 13.0325 - val_mae: 1.4528
# Epoch 1729/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6762 - mae: 1.4509 - val_loss: 13.0333 - val_mae: 1.4547
# Epoch 1730/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6764 - mae: 1.4493 - val_loss: 13.0392 - val_mae: 1.4482
# Epoch 1731/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6719 - mae: 1.4450 - val_loss: 13.0378 - val_mae: 1.4495
# Epoch 1732/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6760 - mae: 1.4491 - val_loss: 13.0293 - val_mae: 1.4553
# Epoch 1733/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6678 - mae: 1.4513 - val_loss: 13.0282 - val_mae: 1.4526
# Epoch 1734/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.6690 - mae: 1.4470 - val_loss: 13.0355 - val_mae: 1.4473
# Epoch 1735/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6700 - mae: 1.4460 - val_loss: 13.0253 - val_mae: 1.4513
# Epoch 1736/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.6654 - mae: 1.4486 - val_loss: 13.0227 - val_mae: 1.4522
# Epoch 1737/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6645 - mae: 1.4502 - val_loss: 13.0199 - val_mae: 1.4520
# Epoch 1738/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6622 - mae: 1.4471 - val_loss: 13.0248 - val_mae: 1.4473
# Epoch 1739/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6643 - mae: 1.4434 - val_loss: 13.0250 - val_mae: 1.4470
# Epoch 1740/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6598 - mae: 1.4472 - val_loss: 13.0172 - val_mae: 1.4547
# Epoch 1741/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6598 - mae: 1.4516 - val_loss: 13.0169 - val_mae: 1.4542
# Epoch 1742/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6593 - mae: 1.4515 - val_loss: 13.0149 - val_mae: 1.4527
# Epoch 1743/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6538 - mae: 1.4473 - val_loss: 13.0207 - val_mae: 1.4465
# Epoch 1744/2600
# 4/4 [==============================] - 0s 85ms/step - loss: 12.6595 - mae: 1.4441 - val_loss: 13.0143 - val_mae: 1.4475
# Epoch 1745/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.6628 - mae: 1.4470 - val_loss: 13.0078 - val_mae: 1.4519
# Epoch 1746/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6556 - mae: 1.4486 - val_loss: 13.0127 - val_mae: 1.4511
# Epoch 1747/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.6540 - mae: 1.4465 - val_loss: 13.0119 - val_mae: 1.4487
# Epoch 1748/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6509 - mae: 1.4450 - val_loss: 13.0106 - val_mae: 1.4487
# Epoch 1749/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6511 - mae: 1.4476 - val_loss: 13.0071 - val_mae: 1.4514
# Epoch 1750/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6480 - mae: 1.4492 - val_loss: 13.0033 - val_mae: 1.4529
# Epoch 1751/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.6468 - mae: 1.4506 - val_loss: 13.0020 - val_mae: 1.4523
# Epoch 1752/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6448 - mae: 1.4485 - val_loss: 13.0041 - val_mae: 1.4487
# Epoch 1753/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6459 - mae: 1.4466 - val_loss: 13.0019 - val_mae: 1.4497
# Epoch 1754/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6429 - mae: 1.4466 - val_loss: 13.0026 - val_mae: 1.4487
# Epoch 1755/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6486 - mae: 1.4443 - val_loss: 13.0039 - val_mae: 1.4474
# Epoch 1756/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6414 - mae: 1.4470 - val_loss: 13.0020 - val_mae: 1.4531
# Epoch 1757/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6455 - mae: 1.4521 - val_loss: 13.0016 - val_mae: 1.4548
# Epoch 1758/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6393 - mae: 1.4501 - val_loss: 13.0017 - val_mae: 1.4497
# Epoch 1759/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6378 - mae: 1.4451 - val_loss: 13.0036 - val_mae: 1.4457
# Epoch 1760/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6381 - mae: 1.4449 - val_loss: 12.9939 - val_mae: 1.4501
# Epoch 1761/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.6359 - mae: 1.4474 - val_loss: 12.9901 - val_mae: 1.4508
# Epoch 1762/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6345 - mae: 1.4486 - val_loss: 12.9872 - val_mae: 1.4523
# Epoch 1763/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6431 - mae: 1.4479 - val_loss: 12.9916 - val_mae: 1.4481
# Epoch 1764/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6321 - mae: 1.4473 - val_loss: 12.9840 - val_mae: 1.4527
# Epoch 1765/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6350 - mae: 1.4515 - val_loss: 12.9871 - val_mae: 1.4542
# Epoch 1766/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6349 - mae: 1.4487 - val_loss: 12.9934 - val_mae: 1.4472
# Epoch 1767/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.6303 - mae: 1.4450 - val_loss: 12.9898 - val_mae: 1.4476
# Epoch 1768/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.6305 - mae: 1.4468 - val_loss: 12.9858 - val_mae: 1.4511
# Epoch 1769/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6320 - mae: 1.4472 - val_loss: 12.9842 - val_mae: 1.4492
# Epoch 1770/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6292 - mae: 1.4486 - val_loss: 12.9784 - val_mae: 1.4542
# Epoch 1771/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6307 - mae: 1.4492 - val_loss: 12.9791 - val_mae: 1.4504
# Epoch 1772/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6245 - mae: 1.4466 - val_loss: 12.9803 - val_mae: 1.4481
# Epoch 1773/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.6255 - mae: 1.4456 - val_loss: 12.9819 - val_mae: 1.4481
# Epoch 1774/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6209 - mae: 1.4457 - val_loss: 12.9795 - val_mae: 1.4502
# Epoch 1775/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6213 - mae: 1.4467 - val_loss: 12.9798 - val_mae: 1.4504
# Epoch 1776/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6350 - mae: 1.4518 - val_loss: 12.9791 - val_mae: 1.4565
# Epoch 1777/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.6236 - mae: 1.4493 - val_loss: 12.9839 - val_mae: 1.4456
# Epoch 1778/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6312 - mae: 1.4404 - val_loss: 12.9897 - val_mae: 1.4431
# Epoch 1779/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6183 - mae: 1.4440 - val_loss: 12.9715 - val_mae: 1.4527
# Epoch 1780/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.6203 - mae: 1.4518 - val_loss: 12.9699 - val_mae: 1.4555
# Epoch 1781/2600
# 4/4 [==============================] - 0s 92ms/step - loss: 12.6170 - mae: 1.4534 - val_loss: 12.9664 - val_mae: 1.4546
# Epoch 1782/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6134 - mae: 1.4491 - val_loss: 12.9676 - val_mae: 1.4483
# Epoch 1783/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6128 - mae: 1.4459 - val_loss: 12.9639 - val_mae: 1.4482
# Epoch 1784/2600
# 4/4 [==============================] - 0s 87ms/step - loss: 12.6113 - mae: 1.4449 - val_loss: 12.9661 - val_mae: 1.4468
# Epoch 1785/2600
# 4/4 [==============================] - 0s 85ms/step - loss: 12.6109 - mae: 1.4448 - val_loss: 12.9642 - val_mae: 1.4483
# Epoch 1786/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6098 - mae: 1.4461 - val_loss: 12.9629 - val_mae: 1.4505
# Epoch 1787/2600
# 4/4 [==============================] - 0s 88ms/step - loss: 12.6102 - mae: 1.4496 - val_loss: 12.9599 - val_mae: 1.4524
# Epoch 1788/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6062 - mae: 1.4486 - val_loss: 12.9640 - val_mae: 1.4489
# Epoch 1789/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6056 - mae: 1.4468 - val_loss: 12.9654 - val_mae: 1.4483
# Epoch 1790/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6076 - mae: 1.4440 - val_loss: 12.9709 - val_mae: 1.4464
# Epoch 1791/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6036 - mae: 1.4446 - val_loss: 12.9652 - val_mae: 1.4492
# Epoch 1792/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.6042 - mae: 1.4463 - val_loss: 12.9638 - val_mae: 1.4492
# Epoch 1793/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.6059 - mae: 1.4491 - val_loss: 12.9559 - val_mae: 1.4536
# Epoch 1794/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6015 - mae: 1.4503 - val_loss: 12.9573 - val_mae: 1.4505
# Epoch 1795/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6089 - mae: 1.4444 - val_loss: 12.9643 - val_mae: 1.4443
# Epoch 1796/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.6042 - mae: 1.4440 - val_loss: 12.9508 - val_mae: 1.4506
# Epoch 1797/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5999 - mae: 1.4490 - val_loss: 12.9507 - val_mae: 1.4516
# Epoch 1798/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.6006 - mae: 1.4492 - val_loss: 12.9478 - val_mae: 1.4498
# Epoch 1799/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5962 - mae: 1.4444 - val_loss: 12.9592 - val_mae: 1.4437
# Epoch 1800/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5972 - mae: 1.4412 - val_loss: 12.9580 - val_mae: 1.4445
# Epoch 1801/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5992 - mae: 1.4435 - val_loss: 12.9493 - val_mae: 1.4488
# Epoch 1802/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5927 - mae: 1.4491 - val_loss: 12.9465 - val_mae: 1.4544
# Epoch 1803/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.6006 - mae: 1.4520 - val_loss: 12.9473 - val_mae: 1.4520
# Epoch 1804/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5909 - mae: 1.4486 - val_loss: 12.9500 - val_mae: 1.4490
# Epoch 1805/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5903 - mae: 1.4468 - val_loss: 12.9499 - val_mae: 1.4485
# Epoch 1806/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5922 - mae: 1.4471 - val_loss: 12.9472 - val_mae: 1.4497
# Epoch 1807/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5881 - mae: 1.4450 - val_loss: 12.9523 - val_mae: 1.4456
# Epoch 1808/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5908 - mae: 1.4419 - val_loss: 12.9525 - val_mae: 1.4453
# Epoch 1809/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5870 - mae: 1.4453 - val_loss: 12.9412 - val_mae: 1.4510
# Epoch 1810/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5869 - mae: 1.4497 - val_loss: 12.9381 - val_mae: 1.4522
# Epoch 1811/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.5894 - mae: 1.4471 - val_loss: 12.9396 - val_mae: 1.4470
# Epoch 1812/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5848 - mae: 1.4459 - val_loss: 12.9342 - val_mae: 1.4500
# Epoch 1813/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.5858 - mae: 1.4492 - val_loss: 12.9335 - val_mae: 1.4511
# Epoch 1814/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.5837 - mae: 1.4460 - val_loss: 12.9416 - val_mae: 1.4450
# Epoch 1815/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5865 - mae: 1.4427 - val_loss: 12.9408 - val_mae: 1.4462
# Epoch 1816/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5843 - mae: 1.4468 - val_loss: 12.9318 - val_mae: 1.4515
# Epoch 1817/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.5853 - mae: 1.4509 - val_loss: 12.9293 - val_mae: 1.4514
# Epoch 1818/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5805 - mae: 1.4447 - val_loss: 12.9444 - val_mae: 1.4428
# Epoch 1819/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5807 - mae: 1.4415 - val_loss: 12.9393 - val_mae: 1.4457
# Epoch 1820/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5752 - mae: 1.4446 - val_loss: 12.9318 - val_mae: 1.4500
# Epoch 1821/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5789 - mae: 1.4497 - val_loss: 12.9314 - val_mae: 1.4546
# Epoch 1822/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5775 - mae: 1.4494 - val_loss: 12.9338 - val_mae: 1.4483
# Epoch 1823/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5780 - mae: 1.4446 - val_loss: 12.9311 - val_mae: 1.4465
# Epoch 1824/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5719 - mae: 1.4444 - val_loss: 12.9281 - val_mae: 1.4479
# Epoch 1825/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5811 - mae: 1.4495 - val_loss: 12.9212 - val_mae: 1.4550
# Epoch 1826/2600
# 4/4 [==============================] - 0s 90ms/step - loss: 12.5771 - mae: 1.4490 - val_loss: 12.9244 - val_mae: 1.4469
# Epoch 1827/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5704 - mae: 1.4445 - val_loss: 12.9257 - val_mae: 1.4470
# Epoch 1828/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.5712 - mae: 1.4443 - val_loss: 12.9229 - val_mae: 1.4468
# Epoch 1829/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.5707 - mae: 1.4437 - val_loss: 12.9247 - val_mae: 1.4471
# Epoch 1830/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.5675 - mae: 1.4459 - val_loss: 12.9233 - val_mae: 1.4494
# Epoch 1831/2600
# 4/4 [==============================] - 0s 94ms/step - loss: 12.5655 - mae: 1.4476 - val_loss: 12.9227 - val_mae: 1.4500
# Epoch 1832/2600
# 4/4 [==============================] - 0s 106ms/step - loss: 12.5660 - mae: 1.4481 - val_loss: 12.9218 - val_mae: 1.4494
# Epoch 1833/2600
# 4/4 [==============================] - 0s 93ms/step - loss: 12.5666 - mae: 1.4470 - val_loss: 12.9181 - val_mae: 1.4486
# Epoch 1834/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5634 - mae: 1.4466 - val_loss: 12.9171 - val_mae: 1.4483
# Epoch 1835/2600
# 4/4 [==============================] - 0s 86ms/step - loss: 12.5646 - mae: 1.4473 - val_loss: 12.9176 - val_mae: 1.4497
# Epoch 1836/2600
# 4/4 [==============================] - 0s 85ms/step - loss: 12.5630 - mae: 1.4478 - val_loss: 12.9180 - val_mae: 1.4486
# Epoch 1837/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5646 - mae: 1.4430 - val_loss: 12.9335 - val_mae: 1.4420
# Epoch 1838/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5652 - mae: 1.4401 - val_loss: 12.9216 - val_mae: 1.4460
# Epoch 1839/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.5644 - mae: 1.4480 - val_loss: 12.9159 - val_mae: 1.4536
# Epoch 1840/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5606 - mae: 1.4510 - val_loss: 12.9142 - val_mae: 1.4508
# Epoch 1841/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5545 - mae: 1.4458 - val_loss: 12.9195 - val_mae: 1.4438
# Epoch 1842/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5720 - mae: 1.4391 - val_loss: 12.9296 - val_mae: 1.4410
# Epoch 1843/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5568 - mae: 1.4419 - val_loss: 12.9082 - val_mae: 1.4510
# Epoch 1844/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5565 - mae: 1.4514 - val_loss: 12.9059 - val_mae: 1.4564
# Epoch 1845/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5576 - mae: 1.4515 - val_loss: 12.9055 - val_mae: 1.4499
# Epoch 1846/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5511 - mae: 1.4463 - val_loss: 12.9108 - val_mae: 1.4465
# Epoch 1847/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.5527 - mae: 1.4433 - val_loss: 12.9130 - val_mae: 1.4455
# Epoch 1848/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5510 - mae: 1.4445 - val_loss: 12.9058 - val_mae: 1.4490
# Epoch 1849/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5519 - mae: 1.4478 - val_loss: 12.9039 - val_mae: 1.4505
# Epoch 1850/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5513 - mae: 1.4493 - val_loss: 12.9004 - val_mae: 1.4510
# Epoch 1851/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5470 - mae: 1.4465 - val_loss: 12.9060 - val_mae: 1.4453
# Epoch 1852/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5566 - mae: 1.4415 - val_loss: 12.9113 - val_mae: 1.4438
# Epoch 1853/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5492 - mae: 1.4433 - val_loss: 12.9019 - val_mae: 1.4505
# Epoch 1854/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.5506 - mae: 1.4503 - val_loss: 12.9006 - val_mae: 1.4525
# Epoch 1855/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.5461 - mae: 1.4478 - val_loss: 12.9042 - val_mae: 1.4462
# Epoch 1856/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5439 - mae: 1.4427 - val_loss: 12.9088 - val_mae: 1.4436
# Epoch 1857/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5435 - mae: 1.4412 - val_loss: 12.9031 - val_mae: 1.4457
# Epoch 1858/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5538 - mae: 1.4473 - val_loss: 12.8941 - val_mae: 1.4539
# Epoch 1859/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5504 - mae: 1.4482 - val_loss: 12.9002 - val_mae: 1.4468
# Epoch 1860/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5407 - mae: 1.4439 - val_loss: 12.8991 - val_mae: 1.4468
# Epoch 1861/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5398 - mae: 1.4449 - val_loss: 12.8964 - val_mae: 1.4488
# Epoch 1862/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5388 - mae: 1.4479 - val_loss: 12.8904 - val_mae: 1.4529
# Epoch 1863/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5421 - mae: 1.4508 - val_loss: 12.8857 - val_mae: 1.4512
# Epoch 1864/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5586 - mae: 1.4439 - val_loss: 12.9085 - val_mae: 1.4395
# Epoch 1865/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5436 - mae: 1.4406 - val_loss: 12.8904 - val_mae: 1.4463
# Epoch 1866/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5359 - mae: 1.4461 - val_loss: 12.8836 - val_mae: 1.4511
# Epoch 1867/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.5368 - mae: 1.4478 - val_loss: 12.8868 - val_mae: 1.4488
# Epoch 1868/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5327 - mae: 1.4457 - val_loss: 12.8882 - val_mae: 1.4470
# Epoch 1869/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5376 - mae: 1.4462 - val_loss: 12.8869 - val_mae: 1.4488
# Epoch 1870/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5313 - mae: 1.4450 - val_loss: 12.8901 - val_mae: 1.4451
# Epoch 1871/2600
# 4/4 [==============================] - 0s 86ms/step - loss: 12.5309 - mae: 1.4427 - val_loss: 12.8912 - val_mae: 1.4448
# Epoch 1872/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.5310 - mae: 1.4443 - val_loss: 12.8852 - val_mae: 1.4482
# Epoch 1873/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5301 - mae: 1.4453 - val_loss: 12.8862 - val_mae: 1.4477
# Epoch 1874/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5369 - mae: 1.4490 - val_loss: 12.8798 - val_mae: 1.4530
# Epoch 1875/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5337 - mae: 1.4493 - val_loss: 12.8828 - val_mae: 1.4458
# Epoch 1876/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5265 - mae: 1.4429 - val_loss: 12.8841 - val_mae: 1.4435
# Epoch 1877/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5289 - mae: 1.4432 - val_loss: 12.8787 - val_mae: 1.4466
# Epoch 1878/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5247 - mae: 1.4450 - val_loss: 12.8781 - val_mae: 1.4474
# Epoch 1879/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.5296 - mae: 1.4465 - val_loss: 12.8774 - val_mae: 1.4474
# Epoch 1880/2600
# 4/4 [==============================] - 0s 85ms/step - loss: 12.5229 - mae: 1.4452 - val_loss: 12.8772 - val_mae: 1.4473
# Epoch 1881/2600
# 4/4 [==============================] - 0s 88ms/step - loss: 12.5233 - mae: 1.4455 - val_loss: 12.8769 - val_mae: 1.4478
# Epoch 1882/2600
# 4/4 [==============================] - 0s 88ms/step - loss: 12.5216 - mae: 1.4452 - val_loss: 12.8804 - val_mae: 1.4471
# Epoch 1883/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5232 - mae: 1.4434 - val_loss: 12.8814 - val_mae: 1.4459
# Epoch 1884/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5215 - mae: 1.4468 - val_loss: 12.8746 - val_mae: 1.4516
# Epoch 1885/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5258 - mae: 1.4502 - val_loss: 12.8737 - val_mae: 1.4496
# Epoch 1886/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.5210 - mae: 1.4452 - val_loss: 12.8777 - val_mae: 1.4449
# Epoch 1887/2600
# 4/4 [==============================] - 0s 85ms/step - loss: 12.5195 - mae: 1.4415 - val_loss: 12.8806 - val_mae: 1.4431
# Epoch 1888/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.5176 - mae: 1.4415 - val_loss: 12.8714 - val_mae: 1.4459
# Epoch 1889/2600
# 4/4 [==============================] - 0s 85ms/step - loss: 12.5160 - mae: 1.4449 - val_loss: 12.8705 - val_mae: 1.4497
# Epoch 1890/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.5207 - mae: 1.4494 - val_loss: 12.8699 - val_mae: 1.4520
# Epoch 1891/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5144 - mae: 1.4466 - val_loss: 12.8770 - val_mae: 1.4438
# Epoch 1892/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.5172 - mae: 1.4403 - val_loss: 12.8811 - val_mae: 1.4422
# Epoch 1893/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5166 - mae: 1.4406 - val_loss: 12.8726 - val_mae: 1.4467
# Epoch 1894/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5234 - mae: 1.4500 - val_loss: 12.8660 - val_mae: 1.4562
# Epoch 1895/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5146 - mae: 1.4516 - val_loss: 12.8687 - val_mae: 1.4487
# Epoch 1896/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5080 - mae: 1.4448 - val_loss: 12.8728 - val_mae: 1.4445
# Epoch 1897/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.5124 - mae: 1.4406 - val_loss: 12.8760 - val_mae: 1.4428
# Epoch 1898/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5099 - mae: 1.4413 - val_loss: 12.8698 - val_mae: 1.4464
# Epoch 1899/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.5260 - mae: 1.4497 - val_loss: 12.8584 - val_mae: 1.4535
# Epoch 1900/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5108 - mae: 1.4503 - val_loss: 12.8551 - val_mae: 1.4489
# Epoch 1901/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5154 - mae: 1.4425 - val_loss: 12.8774 - val_mae: 1.4398
# Epoch 1902/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5106 - mae: 1.4387 - val_loss: 12.8687 - val_mae: 1.4444
# Epoch 1903/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5036 - mae: 1.4454 - val_loss: 12.8596 - val_mae: 1.4518
# Epoch 1904/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5121 - mae: 1.4513 - val_loss: 12.8603 - val_mae: 1.4527
# Epoch 1905/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.5078 - mae: 1.4482 - val_loss: 12.8627 - val_mae: 1.4448
# Epoch 1906/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5036 - mae: 1.4412 - val_loss: 12.8676 - val_mae: 1.4427
# Epoch 1907/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5069 - mae: 1.4427 - val_loss: 12.8586 - val_mae: 1.4482
# Epoch 1908/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5042 - mae: 1.4477 - val_loss: 12.8519 - val_mae: 1.4500
# Epoch 1909/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.4985 - mae: 1.4469 - val_loss: 12.8548 - val_mae: 1.4457
# Epoch 1910/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.5052 - mae: 1.4420 - val_loss: 12.8584 - val_mae: 1.4439
# Epoch 1911/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.5046 - mae: 1.4409 - val_loss: 12.8590 - val_mae: 1.4449
# Epoch 1912/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.5016 - mae: 1.4464 - val_loss: 12.8514 - val_mae: 1.4517
# Epoch 1913/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5002 - mae: 1.4499 - val_loss: 12.8504 - val_mae: 1.4505
# Epoch 1914/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.4977 - mae: 1.4458 - val_loss: 12.8566 - val_mae: 1.4449
# Epoch 1915/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.5111 - mae: 1.4404 - val_loss: 12.8643 - val_mae: 1.4423
# Epoch 1916/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.5056 - mae: 1.4448 - val_loss: 12.8478 - val_mae: 1.4520
# Epoch 1917/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.4969 - mae: 1.4498 - val_loss: 12.8477 - val_mae: 1.4510
# Epoch 1918/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.4924 - mae: 1.4472 - val_loss: 12.8553 - val_mae: 1.4450
# Epoch 1919/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.4913 - mae: 1.4416 - val_loss: 12.8605 - val_mae: 1.4420
# Epoch 1920/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.4960 - mae: 1.4391 - val_loss: 12.8611 - val_mae: 1.4411
# Epoch 1921/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.4927 - mae: 1.4419 - val_loss: 12.8455 - val_mae: 1.4492
# Epoch 1922/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.4913 - mae: 1.4476 - val_loss: 12.8433 - val_mae: 1.4512
# Epoch 1923/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.4912 - mae: 1.4486 - val_loss: 12.8464 - val_mae: 1.4496
# Epoch 1924/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.4877 - mae: 1.4455 - val_loss: 12.8529 - val_mae: 1.4453
# Epoch 1925/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.4921 - mae: 1.4413 - val_loss: 12.8566 - val_mae: 1.4430
# Epoch 1926/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.4961 - mae: 1.4440 - val_loss: 12.8434 - val_mae: 1.4506
# Epoch 1927/2600
# 4/4 [==============================] - 0s 88ms/step - loss: 12.4919 - mae: 1.4481 - val_loss: 12.8399 - val_mae: 1.4486
# Epoch 1928/2600
# 4/4 [==============================] - 0s 87ms/step - loss: 12.4848 - mae: 1.4452 - val_loss: 12.8451 - val_mae: 1.4451
# Epoch 1929/2600
# 4/4 [==============================] - 0s 93ms/step - loss: 12.4853 - mae: 1.4422 - val_loss: 12.8475 - val_mae: 1.4447
# Epoch 1930/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.4866 - mae: 1.4444 - val_loss: 12.8393 - val_mae: 1.4494
# Epoch 1931/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.4864 - mae: 1.4467 - val_loss: 12.8411 - val_mae: 1.4469
# Epoch 1932/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.4848 - mae: 1.4433 - val_loss: 12.8441 - val_mae: 1.4450
# Epoch 1933/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.4814 - mae: 1.4444 - val_loss: 12.8369 - val_mae: 1.4488
# Epoch 1934/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.4812 - mae: 1.4468 - val_loss: 12.8344 - val_mae: 1.4490
# Epoch 1935/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.4898 - mae: 1.4490 - val_loss: 12.8336 - val_mae: 1.4492
# Epoch 1936/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.4797 - mae: 1.4437 - val_loss: 12.8466 - val_mae: 1.4413
# Epoch 1937/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.4902 - mae: 1.4376 - val_loss: 12.8525 - val_mae: 1.4405
# Epoch 1938/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.4914 - mae: 1.4437 - val_loss: 12.8351 - val_mae: 1.4508
# Epoch 1939/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.4843 - mae: 1.4465 - val_loss: 12.8361 - val_mae: 1.4467
# Epoch 1940/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.4791 - mae: 1.4463 - val_loss: 12.8311 - val_mae: 1.4490
# Epoch 1941/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.4771 - mae: 1.4465 - val_loss: 12.8309 - val_mae: 1.4476
# Epoch 1942/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.4753 - mae: 1.4442 - val_loss: 12.8376 - val_mae: 1.4445
# Epoch 1943/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.4769 - mae: 1.4411 - val_loss: 12.8377 - val_mae: 1.4433
# Epoch 1944/2600
# 4/4 [==============================] - 0s 78ms/step - loss: 12.4796 - mae: 1.4441 - val_loss: 12.8288 - val_mae: 1.4491
# Epoch 1945/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.4739 - mae: 1.4459 - val_loss: 12.8306 - val_mae: 1.4459
# Epoch 1946/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.4728 - mae: 1.4429 - val_loss: 12.8312 - val_mae: 1.4447
# Epoch 1947/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.4731 - mae: 1.4436 - val_loss: 12.8271 - val_mae: 1.4460
# Epoch 1948/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.4723 - mae: 1.4438 - val_loss: 12.8277 - val_mae: 1.4462
# Epoch 1949/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.4746 - mae: 1.4470 - val_loss: 12.8237 - val_mae: 1.4512
# Epoch 1950/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.4703 - mae: 1.4477 - val_loss: 12.8271 - val_mae: 1.4471
# Epoch 1951/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.4676 - mae: 1.4440 - val_loss: 12.8325 - val_mae: 1.4433
# Epoch 1952/2600
# ...
# Epoch 2484/2600
# 4/4 [==============================] - 0s 85ms/step - loss: 12.2110 - mae: 1.4387 - val_loss: 12.6174 - val_mae: 1.4459
# Epoch 2485/2600
# 4/4 [==============================] - 0s 89ms/step - loss: 12.2015 - mae: 1.4414 - val_loss: 12.6231 - val_mae: 1.4422
# Epoch 2486/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.2083 - mae: 1.4352 - val_loss: 12.6513 - val_mae: 1.4354
# Epoch 2487/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.2076 - mae: 1.4320 - val_loss: 12.6382 - val_mae: 1.4390
# Epoch 2488/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.2003 - mae: 1.4386 - val_loss: 12.6208 - val_mae: 1.4486
# Epoch 2489/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.2061 - mae: 1.4435 - val_loss: 12.6213 - val_mae: 1.4456
# Epoch 2490/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1999 - mae: 1.4389 - val_loss: 12.6317 - val_mae: 1.4396
# Epoch 2491/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1999 - mae: 1.4351 - val_loss: 12.6305 - val_mae: 1.4396
# Epoch 2492/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.2017 - mae: 1.4382 - val_loss: 12.6171 - val_mae: 1.4440
# Epoch 2493/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1997 - mae: 1.4402 - val_loss: 12.6162 - val_mae: 1.4430
# Epoch 2494/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1963 - mae: 1.4379 - val_loss: 12.6244 - val_mae: 1.4390
# Epoch 2495/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.2010 - mae: 1.4337 - val_loss: 12.6346 - val_mae: 1.4370
# Epoch 2496/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1979 - mae: 1.4352 - val_loss: 12.6184 - val_mae: 1.4431
# Epoch 2497/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.2008 - mae: 1.4395 - val_loss: 12.6202 - val_mae: 1.4431
# Epoch 2498/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1959 - mae: 1.4398 - val_loss: 12.6173 - val_mae: 1.4450
# Epoch 2499/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1977 - mae: 1.4411 - val_loss: 12.6186 - val_mae: 1.4425
# Epoch 2500/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.1950 - mae: 1.4372 - val_loss: 12.6327 - val_mae: 1.4383
# Epoch 2501/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1965 - mae: 1.4335 - val_loss: 12.6375 - val_mae: 1.4369
# Epoch 2502/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1955 - mae: 1.4340 - val_loss: 12.6256 - val_mae: 1.4411
# Epoch 2503/2600
# 4/4 [==============================] - 0s 92ms/step - loss: 12.1953 - mae: 1.4395 - val_loss: 12.6164 - val_mae: 1.4473
# Epoch 2504/2600
# 4/4 [==============================] - 0s 95ms/step - loss: 12.2073 - mae: 1.4396 - val_loss: 12.6226 - val_mae: 1.4421
# Epoch 2505/2600
# 4/4 [==============================] - 0s 85ms/step - loss: 12.1944 - mae: 1.4385 - val_loss: 12.6191 - val_mae: 1.4424
# Epoch 2506/2600
# 4/4 [==============================] - 0s 87ms/step - loss: 12.1967 - mae: 1.4374 - val_loss: 12.6205 - val_mae: 1.4418
# Epoch 2507/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.2010 - mae: 1.4413 - val_loss: 12.6090 - val_mae: 1.4468
# Epoch 2508/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1949 - mae: 1.4410 - val_loss: 12.6162 - val_mae: 1.4413
# Epoch 2509/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1961 - mae: 1.4351 - val_loss: 12.6293 - val_mae: 1.4372
# Epoch 2510/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1958 - mae: 1.4329 - val_loss: 12.6349 - val_mae: 1.4369
# Epoch 2511/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1976 - mae: 1.4348 - val_loss: 12.6164 - val_mae: 1.4431
# Epoch 2512/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1928 - mae: 1.4406 - val_loss: 12.6176 - val_mae: 1.4453
# Epoch 2513/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1929 - mae: 1.4400 - val_loss: 12.6238 - val_mae: 1.4427
# Epoch 2514/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1907 - mae: 1.4374 - val_loss: 12.6263 - val_mae: 1.4399
# Epoch 2515/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1928 - mae: 1.4347 - val_loss: 12.6264 - val_mae: 1.4389
# Epoch 2516/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.1926 - mae: 1.4347 - val_loss: 12.6209 - val_mae: 1.4416
# Epoch 2517/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1973 - mae: 1.4414 - val_loss: 12.6082 - val_mae: 1.4483
# Epoch 2518/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1959 - mae: 1.4419 - val_loss: 12.6084 - val_mae: 1.4416
# Epoch 2519/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1884 - mae: 1.4360 - val_loss: 12.6247 - val_mae: 1.4354
# Epoch 2520/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1958 - mae: 1.4302 - val_loss: 12.6345 - val_mae: 1.4346
# Epoch 2521/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1896 - mae: 1.4330 - val_loss: 12.6170 - val_mae: 1.4419
# Epoch 2522/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1881 - mae: 1.4394 - val_loss: 12.6135 - val_mae: 1.4458
# Epoch 2523/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.1910 - mae: 1.4414 - val_loss: 12.6135 - val_mae: 1.4442
# Epoch 2524/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.1868 - mae: 1.4391 - val_loss: 12.6203 - val_mae: 1.4405
# Epoch 2525/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.1879 - mae: 1.4360 - val_loss: 12.6248 - val_mae: 1.4390
# Epoch 2526/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1885 - mae: 1.4351 - val_loss: 12.6216 - val_mae: 1.4402
# Epoch 2527/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1875 - mae: 1.4367 - val_loss: 12.6212 - val_mae: 1.4420
# Epoch 2528/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.1870 - mae: 1.4374 - val_loss: 12.6204 - val_mae: 1.4421
# Epoch 2529/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.1882 - mae: 1.4366 - val_loss: 12.6246 - val_mae: 1.4404
# Epoch 2530/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1865 - mae: 1.4368 - val_loss: 12.6196 - val_mae: 1.4430
# Epoch 2531/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1902 - mae: 1.4374 - val_loss: 12.6210 - val_mae: 1.4411
# Epoch 2532/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1866 - mae: 1.4387 - val_loss: 12.6086 - val_mae: 1.4444
# Epoch 2533/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1894 - mae: 1.4384 - val_loss: 12.6188 - val_mae: 1.4399
# Epoch 2534/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1847 - mae: 1.4363 - val_loss: 12.6125 - val_mae: 1.4406
# Epoch 2535/2600
# 4/4 [==============================] - 0s 94ms/step - loss: 12.1869 - mae: 1.4381 - val_loss: 12.6093 - val_mae: 1.4416
# Epoch 2536/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1887 - mae: 1.4380 - val_loss: 12.6159 - val_mae: 1.4399
# Epoch 2537/2600
# 4/4 [==============================] - 0s 85ms/step - loss: 12.1821 - mae: 1.4356 - val_loss: 12.6231 - val_mae: 1.4382
# Epoch 2538/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.1879 - mae: 1.4333 - val_loss: 12.6311 - val_mae: 1.4375
# Epoch 2539/2600
# 4/4 [==============================] - 0s 88ms/step - loss: 12.1975 - mae: 1.4383 - val_loss: 12.6078 - val_mae: 1.4453
# Epoch 2540/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.1854 - mae: 1.4396 - val_loss: 12.6198 - val_mae: 1.4401
# Epoch 2541/2600
# 4/4 [==============================] - 0s 87ms/step - loss: 12.1856 - mae: 1.4367 - val_loss: 12.6164 - val_mae: 1.4411
# Epoch 2542/2600
# 4/4 [==============================] - 0s 86ms/step - loss: 12.1827 - mae: 1.4353 - val_loss: 12.6223 - val_mae: 1.4383
# Epoch 2543/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1808 - mae: 1.4346 - val_loss: 12.6189 - val_mae: 1.4404
# Epoch 2544/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1879 - mae: 1.4391 - val_loss: 12.6090 - val_mae: 1.4448
# Epoch 2545/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1858 - mae: 1.4383 - val_loss: 12.6218 - val_mae: 1.4398
# Epoch 2546/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1805 - mae: 1.4358 - val_loss: 12.6192 - val_mae: 1.4401
# Epoch 2547/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.2092 - mae: 1.4415 - val_loss: 12.6099 - val_mae: 1.4453
# Epoch 2548/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1872 - mae: 1.4373 - val_loss: 12.6383 - val_mae: 1.4352
# Epoch 2549/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1848 - mae: 1.4316 - val_loss: 12.6246 - val_mae: 1.4382
# Epoch 2550/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.1851 - mae: 1.4338 - val_loss: 12.6143 - val_mae: 1.4416
# Epoch 2551/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1819 - mae: 1.4401 - val_loss: 12.6069 - val_mae: 1.4470
# Epoch 2552/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1834 - mae: 1.4427 - val_loss: 12.6049 - val_mae: 1.4451
# Epoch 2553/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1782 - mae: 1.4398 - val_loss: 12.6120 - val_mae: 1.4403
# Epoch 2554/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1764 - mae: 1.4343 - val_loss: 12.6276 - val_mae: 1.4352
# Epoch 2555/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.1881 - mae: 1.4327 - val_loss: 12.6152 - val_mae: 1.4392
# Epoch 2556/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.1788 - mae: 1.4369 - val_loss: 12.6108 - val_mae: 1.4425
# Epoch 2557/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1777 - mae: 1.4386 - val_loss: 12.6127 - val_mae: 1.4422
# Epoch 2558/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1792 - mae: 1.4359 - val_loss: 12.6210 - val_mae: 1.4381
# Epoch 2559/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1832 - mae: 1.4328 - val_loss: 12.6336 - val_mae: 1.4365
# Epoch 2560/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.1750 - mae: 1.4346 - val_loss: 12.6141 - val_mae: 1.4439
# Epoch 2561/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1871 - mae: 1.4428 - val_loss: 12.6040 - val_mae: 1.4501
# Epoch 2562/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1779 - mae: 1.4433 - val_loss: 12.6132 - val_mae: 1.4419
# Epoch 2563/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1852 - mae: 1.4347 - val_loss: 12.6250 - val_mae: 1.4371
# Epoch 2564/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1767 - mae: 1.4337 - val_loss: 12.6104 - val_mae: 1.4393
# Epoch 2565/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.1860 - mae: 1.4387 - val_loss: 12.6002 - val_mae: 1.4440
# Epoch 2566/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1777 - mae: 1.4371 - val_loss: 12.6124 - val_mae: 1.4385
# Epoch 2567/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.1835 - mae: 1.4332 - val_loss: 12.6249 - val_mae: 1.4367
# Epoch 2568/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.1901 - mae: 1.4369 - val_loss: 12.6055 - val_mae: 1.4450
# Epoch 2569/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1855 - mae: 1.4368 - val_loss: 12.6199 - val_mae: 1.4387
# Epoch 2570/2600
# 4/4 [==============================] - 0s 79ms/step - loss: 12.1777 - mae: 1.4372 - val_loss: 12.6065 - val_mae: 1.4430
# Epoch 2571/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1741 - mae: 1.4375 - val_loss: 12.6160 - val_mae: 1.4399
# Epoch 2572/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1782 - mae: 1.4373 - val_loss: 12.6071 - val_mae: 1.4433
# Epoch 2573/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1750 - mae: 1.4361 - val_loss: 12.6222 - val_mae: 1.4380
# Epoch 2574/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1723 - mae: 1.4339 - val_loss: 12.6159 - val_mae: 1.4398
# Epoch 2575/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1716 - mae: 1.4360 - val_loss: 12.6079 - val_mae: 1.4437
# Epoch 2576/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1719 - mae: 1.4396 - val_loss: 12.6082 - val_mae: 1.4441
# Epoch 2577/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1793 - mae: 1.4384 - val_loss: 12.6116 - val_mae: 1.4412
# Epoch 2578/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1704 - mae: 1.4376 - val_loss: 12.6060 - val_mae: 1.4429
# Epoch 2579/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1788 - mae: 1.4406 - val_loss: 12.5987 - val_mae: 1.4439
# Epoch 2580/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.1855 - mae: 1.4346 - val_loss: 12.6274 - val_mae: 1.4340
# Epoch 2581/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1732 - mae: 1.4317 - val_loss: 12.6059 - val_mae: 1.4401
# Epoch 2582/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1767 - mae: 1.4359 - val_loss: 12.6076 - val_mae: 1.4406
# Epoch 2583/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1735 - mae: 1.4396 - val_loss: 12.5990 - val_mae: 1.4462
# Epoch 2584/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1771 - mae: 1.4394 - val_loss: 12.6073 - val_mae: 1.4416
# Epoch 2585/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1700 - mae: 1.4381 - val_loss: 12.6064 - val_mae: 1.4419
# Epoch 2586/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.1699 - mae: 1.4351 - val_loss: 12.6201 - val_mae: 1.4366
# Epoch 2587/2600
# 4/4 [==============================] - 0s 86ms/step - loss: 12.1724 - mae: 1.4323 - val_loss: 12.6207 - val_mae: 1.4379
# Epoch 2588/2600
# 4/4 [==============================] - 0s 90ms/step - loss: 12.1697 - mae: 1.4350 - val_loss: 12.6065 - val_mae: 1.4413
# Epoch 2589/2600
# 4/4 [==============================] - 0s 84ms/step - loss: 12.1671 - mae: 1.4368 - val_loss: 12.6084 - val_mae: 1.4418
# Epoch 2590/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1684 - mae: 1.4371 - val_loss: 12.6066 - val_mae: 1.4424
# Epoch 2591/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1723 - mae: 1.4404 - val_loss: 12.5990 - val_mae: 1.4456
# Epoch 2592/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1661 - mae: 1.4409 - val_loss: 12.6066 - val_mae: 1.4418
# Epoch 2593/2600
# 4/4 [==============================] - 0s 80ms/step - loss: 12.1735 - mae: 1.4344 - val_loss: 12.6320 - val_mae: 1.4352
# Epoch 2594/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1707 - mae: 1.4334 - val_loss: 12.6080 - val_mae: 1.4410
# Epoch 2595/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1681 - mae: 1.4363 - val_loss: 12.6116 - val_mae: 1.4410
# Epoch 2596/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1660 - mae: 1.4374 - val_loss: 12.6077 - val_mae: 1.4428
# Epoch 2597/2600
# 4/4 [==============================] - 0s 81ms/step - loss: 12.1676 - mae: 1.4380 - val_loss: 12.6030 - val_mae: 1.4428
# Epoch 2598/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1709 - mae: 1.4362 - val_loss: 12.6142 - val_mae: 1.4381
# Epoch 2599/2600
# 4/4 [==============================] - 0s 82ms/step - loss: 12.1664 - mae: 1.4361 - val_loss: 12.6008 - val_mae: 1.4433
# Epoch 2600/2600
# 4/4 [==============================] - 0s 83ms/step - loss: 12.1655 - mae: 1.4372 - val_loss: 12.6044 - val_mae: 1.4402

# %%
# plot learning curves
plt.title('Learning Curves')
plt.xlabel('Epoch')
plt.ylabel('MSE loss')
plt.plot((history_fine.history['loss']), label='train')
plt.plot((history_fine.history['val_loss']), label='test')
plt.legend()
plt.show()

# %% [markdown]
# Overfitting can be observed as the training loss continues to decrease with the Epochs, improving the accuracy, while the test loss shows a slower decrease. With more training epochs the test loss should reach an asymptotic value and not decrease anymore.

# %% [markdown]
# ### 7) Testing the trained model on the initial case study
#
# The trained model is now applied to a real case study, the GMI overpass of Medicane Ianos on 16/09/2020 seen before, and the reult will be compared with the surface precipitation estimates provided by the NASA Goddard Profiling Algorithm, the official GPM preciptiation product for the GMI radiometer. Some details on the GPROF algorithm can be found in <a href="https://gpm.nasa.gov/resources/documents/gpm-gprof-algorithm-theoretical-basis-document-atbd/">GPM GPROF Algorithm Theoretical Basis Document (ATBD)  </a>.

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap 
from mpl_toolkits.basemap import Basemap
import numpy as np
import h5py
import warnings

# defining the function to plot
def plot_rr_map(RR,lat,lon,colorAxisMin,colorAxisMax):
    # set the lat/lon borders of the map
    latborders=[34,40]
    lonborders=[14,22]
    m = Basemap(projection='merc',
        resolution='l',
        lat_ts=20,
        llcrnrlat=latborders[0],urcrnrlat=latborders[1],\
        llcrnrlon=lonborders[0],urcrnrlon=lonborders[1])

    
#E set min/max values of the colorbar
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        im1 = m.pcolor(lon[:],lat[:],RR[:],shading='nearest',cmap='turbo',latlon=True,vmin=colorAxisMin,vmax=colorAxisMax)
    m.drawcoastlines()
# set parallels and meridians

    dparal=2 #separation in deg between drawn parallels
    parallels = np.arange(latborders[0],latborders[1],dparal)
    dmerid=2 #separation in deg between drawn meridians
    meridians = np.arange(lonborders[0],lonborders[1],dmerid)
    m.drawparallels(parallels,labels=[1,0,0,0],fontsize=15)
    m.drawmeridians(meridians,labels=[0,0,0,1],fontsize=15) 
# add colorbar.
    cbar = m.colorbar(location='right',pad="5%")
    cbar.set_label('Rainfall Rate [mm/h]')
    
gmi_file_path='./1C-R.GPM.GMI.XCAL2016-C.20200916-S130832-E144106.037225.V07A.HDF5'
hf=h5py.File(gmi_file_path,'r')
lat1=hf['S1/Latitude'][:]
lon1=hf['S1/Longitude'][:]
TB1=hf['S1/Tc'][:]
TB2=hf['S2/Tc'][:]
hf.close()

TB=np.concatenate((TB1,TB2,),axis=2)
TB=np.reshape(TB,(2963*221,13))
TB[np.any(TB<=0,axis=1),:]=np.NaN
TB = scaler.transform(TB)
predictions = model.predict(TB)
predictions = np.reshape(predictions,(2963,221))


gprof_file_path='./2A.GPM.GMI.GPROF2021v1.20200916-S130832-E144106.037225.V07A.HDF5'
hf=h5py.File(gprof_file_path,'r')
lat2=hf['S1/Latitude'][:]
lon2=hf['S1/Longitude'][:]
gprof_rr=hf['S1/surfacePrecipitation'][:]
hf.close()
# Out:
# 20464/20464 [==============================] - 22s 1ms/step

# %%
fig = plt.figure(figsize=(24,16))
ax = fig.add_subplot(121)
plot_rr_map(predictions,lat1,lon1,0,40)
plt.title('Exercise1 model',fontsize=12)
ax = fig.add_subplot(122)
plot_rr_map(gprof_rr,lat2,lon2,0,40)
plt.title('GPROF',fontsize=12)
# Out:
# Text(0.5, 1.0, 'GPROF')

# %% [markdown]
# The result obtained by our NN model seems quite acceptable, the rainfall patterns predicted by our model are quite similar to those of GPROF, which is based on a physically-based Bayesian approach and is a very complex algorithm. It is important to highlight that:
#  1. The GMI observation of Madicane Ianos is not included in the training dataset (training dataset is built from 10 orbits of March 2014, while Medicane Ianos occured on 16/09/2020).
#  2. The NN model precipitation rate estimates over land and coastal areas are not reliable, as the training dataset does not include measurements over land (the precipitation retrieval over land is much more complex than over ocean and it has not been address in this exercise).
#  3. The high rainfall rates are underestimated, probably due to the small size of the training dataset, since intense rainfall is rare and probably it is not well represented in our limited-size training dataset.
#  4. Very low precipitation rates are present also in areas where the GPROF algorithm does not predict any precipitation, since the training dataset includes only pixels with precipitation (rainfall rate > 0 mm/h), and it has not learned how to disciminate between rain and no-rain pixels (precipitation detection is often handled using a different ML approach).
#  5. Remember that the trainig dataset is very small (10 orbits over ocean only) and the NN model obtained with this exercise is not suitable for operational or scientific purposes.

# %% [markdown]
# # Addtional Exercises
#
# Using the following code try to train the model differently. In particular:
#
# 1. try to modify the learning rate and the epoch number (try learning rates 0.01, 0.002, 0.0005 0.0001)
# 2. modify the model architecture, varying the number of perceptrons in each hidden layer (40/10, 20/30)
# 3. try to remove one or more input GMI channels (e.g. the first two at 10 GHz which are more directly impacted by surface precipitation)

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import optimizers
from tensorflow.keras import utils
import tensorflow as tf
from sklearn.model_selection import train_test_split
import numpy as np
import xarray as xr

import warnings
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# model hyperparameters
learning_rate1= 0.001  #the learning rate is the step size at each iteration while moving toward a minimum of a loss function
epochs = 1600          #An epoch in machine learning means one complete pass of the training dataset through the algorithm. 
batch_size = 8000      #the batch size is the number of training examples utilized in one iteration. A large batch size should make the training faster but may lead to memory saturation
num_percept_layer1=20  #number of perceptron 1st hidden layer
num_percept_layer2=10  #number of perceptron 2nd hidden layer



def load_dataset():
    warnings.filterwarnings("ignore")
    data_path = './dataset2_GMI_DPR_RR.nc'
    ds = xr.open_dataset(data_path)
    train_df = ds['tb'].to_dataframe().unstack()
    target = ds['rr'].to_dataframe()
    tensor_df = tf.convert_to_tensor(train_df, dtype=np.float)
    label_df = tf.convert_to_tensor(target, dtype=np.float)
    return tensor_df,label_df

def split_dataset(dataset, label_dataset):
    #split = round(test_split* len(tensor_df))
    choice=np.mod(range(0,len(tensor_df)),2)==0
    X_train = dataset[choice==0]
    X_test = dataset[choice]
    y_train = label_dataset[choice==0]
    y_test = label_dataset[choice]   
    
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = split_dataset(tensor_df, label_df)

# Scaling: Standardize features by removing the mean and scaling to unit variance.
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train) #mean and variance are calculated on the training dataset and applied to the training dataset
X_test_scaled = scaler.transform(X_test)       #mean and variance (previously calculated) are applied to the test dataset

# Set the input shape
input_shape = X_train.shape[1]


def train():
    # here the network achitecture is defined: here it is a feed forward neural network with 2 hidden layers, 
    # Sigmoids are used as transfer function in both hidden layers.
    model = Sequential()
    model.add(Dense(num_percept_layer1, input_dim=input_shape, kernel_initializer='normal', activation='sigmoid'))
    model.add(Dense(num_percept_layer2, kernel_initializer='normal', activation='sigmoid')) ###second hidden
    model.add(Dense(1, kernel_initializer='normal', activation='linear')) #output
    model.summary()
    #the optimizer is the algorithm used for the training. Adam is a standard choice, Scale conjugate gradient (SGD), is also very efficient.
    optimizer = optimizers.Adam(lr=learning_rate1)
    #optimizer = optimizers.experimental.SGD( learning_rate=learning_rate1)
    
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae']) # the loss function to be minimized during training is the mean squared error (MSE)
    history = model.fit(
        X_train_scaled,
        y_train,
        batch_size=batch_size,
        epochs=epochs,
    # We also carry out some validation to
    # monitor loss and metrics on the test dataset
    # at the end of each epoch
        validation_data=(X_test_scaled, y_test),)
        #validation_data=(X_test, np.log10(y_test)),)
    return model, history


verbose = 1
# training with the train dataset
model, history = train()

model.save('./exer2_model.h5')

# plot learning curves
plt.title('Learning Curves')
plt.xlabel('Epoch')
plt.ylabel('MSE loss')
plt.plot((history.history['loss']), label='train')
plt.plot((history.history['val_loss']), label='test')
plt.legend()
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 20)                280
#
#  dense_16 (Dense)            (None, 10)                210
#
#  dense_17 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 501
# Trainable params: 501
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1600
# 4/4 [==============================] - 1s 147ms/step - loss: 31.9574 - mae: 2.4349 - val_loss: 32.9396 - val_mae: 2.4198
# Epoch 2/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 31.8249 - mae: 2.4078 - val_loss: 32.8080 - val_mae: 2.3926
# Epoch 3/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 31.6932 - mae: 2.3806 - val_loss: 32.6761 - val_mae: 2.3651
# Epoch 4/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 31.5612 - mae: 2.3529 - val_loss: 32.5432 - val_mae: 2.3372
# Epoch 5/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 31.4279 - mae: 2.3248 - val_loss: 32.4087 - val_mae: 2.3090
# Epoch 6/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 31.2936 - mae: 2.2968 - val_loss: 32.2718 - val_mae: 2.2815
# Epoch 7/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 31.1554 - mae: 2.2695 - val_loss: 32.1325 - val_mae: 2.2547
# Epoch 8/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 31.0154 - mae: 2.2428 - val_loss: 31.9902 - val_mae: 2.2286
# Epoch 9/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 30.8714 - mae: 2.2168 - val_loss: 31.8448 - val_mae: 2.2032
# Epoch 10/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 30.7252 - mae: 2.1918 - val_loss: 31.6957 - val_mae: 2.1787
# Epoch 11/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 30.5752 - mae: 2.1675 - val_loss: 31.5429 - val_mae: 2.1551
# Epoch 12/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 30.4218 - mae: 2.1441 - val_loss: 31.3865 - val_mae: 2.1325
# Epoch 13/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 30.2641 - mae: 2.1219 - val_loss: 31.2268 - val_mae: 2.1110
# Epoch 14/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 30.1031 - mae: 2.1008 - val_loss: 31.0640 - val_mae: 2.0906
# Epoch 15/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 29.9401 - mae: 2.0807 - val_loss: 30.8983 - val_mae: 2.0714
# Epoch 16/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 29.7730 - mae: 2.0618 - val_loss: 30.7308 - val_mae: 2.0534
# Epoch 17/1600
# 4/4 [==============================] - 0s 86ms/step - loss: 29.6065 - mae: 2.0441 - val_loss: 30.5615 - val_mae: 2.0367
# Epoch 18/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 29.4365 - mae: 2.0278 - val_loss: 30.3918 - val_mae: 2.0213
# Epoch 19/1600
# 4/4 [==============================] - 0s 88ms/step - loss: 29.2680 - mae: 2.0128 - val_loss: 30.2220 - val_mae: 2.0072
# Epoch 20/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 29.0975 - mae: 1.9992 - val_loss: 30.0535 - val_mae: 1.9946
# Epoch 21/1600
# 4/4 [==============================] - 0s 87ms/step - loss: 28.9295 - mae: 1.9870 - val_loss: 29.8865 - val_mae: 1.9833
# Epoch 22/1600
# 4/4 [==============================] - 0s 90ms/step - loss: 28.7645 - mae: 1.9763 - val_loss: 29.7212 - val_mae: 1.9735
# Epoch 23/1600
# 4/4 [==============================] - 0s 90ms/step - loss: 28.6012 - mae: 1.9668 - val_loss: 29.5586 - val_mae: 1.9651
# Epoch 24/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 28.4388 - mae: 1.9587 - val_loss: 29.3999 - val_mae: 1.9581
# Epoch 25/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 28.2823 - mae: 1.9519 - val_loss: 29.2447 - val_mae: 1.9524
# Epoch 26/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 28.1301 - mae: 1.9466 - val_loss: 29.0934 - val_mae: 1.9479
# Epoch 27/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 27.9794 - mae: 1.9423 - val_loss: 28.9472 - val_mae: 1.9447
# Epoch 28/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 27.8349 - mae: 1.9397 - val_loss: 28.8059 - val_mae: 1.9426
# Epoch 29/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 27.6950 - mae: 1.9381 - val_loss: 28.6697 - val_mae: 1.9417
# Epoch 30/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 27.5614 - mae: 1.9373 - val_loss: 28.5384 - val_mae: 1.9419
# Epoch 31/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 27.4326 - mae: 1.9378 - val_loss: 28.4123 - val_mae: 1.9429
# Epoch 32/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 27.3088 - mae: 1.9389 - val_loss: 28.2916 - val_mae: 1.9448
# Epoch 33/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 27.1898 - mae: 1.9411 - val_loss: 28.1763 - val_mae: 1.9475
# Epoch 34/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 27.0775 - mae: 1.9441 - val_loss: 28.0659 - val_mae: 1.9509
# Epoch 35/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 26.9691 - mae: 1.9476 - val_loss: 27.9608 - val_mae: 1.9549
# Epoch 36/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 26.8650 - mae: 1.9517 - val_loss: 27.8610 - val_mae: 1.9595
# Epoch 37/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 26.7670 - mae: 1.9561 - val_loss: 27.7661 - val_mae: 1.9645
# Epoch 38/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 26.6750 - mae: 1.9612 - val_loss: 27.6753 - val_mae: 1.9701
# Epoch 39/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 26.5856 - mae: 1.9663 - val_loss: 27.5892 - val_mae: 1.9758
# Epoch 40/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 26.5006 - mae: 1.9719 - val_loss: 27.5075 - val_mae: 1.9818
# Epoch 41/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 26.4210 - mae: 1.9779 - val_loss: 27.4295 - val_mae: 1.9881
# Epoch 42/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 26.3442 - mae: 1.9840 - val_loss: 27.3555 - val_mae: 1.9944
# Epoch 43/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 26.2716 - mae: 1.9902 - val_loss: 27.2849 - val_mae: 2.0009
# Epoch 44/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 26.2028 - mae: 1.9966 - val_loss: 27.2176 - val_mae: 2.0073
# Epoch 45/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 26.1368 - mae: 2.0030 - val_loss: 27.1534 - val_mae: 2.0139
# Epoch 46/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 26.0743 - mae: 2.0094 - val_loss: 27.0921 - val_mae: 2.0203
# Epoch 47/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 26.0142 - mae: 2.0158 - val_loss: 27.0336 - val_mae: 2.0268
# Epoch 48/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 25.9567 - mae: 2.0222 - val_loss: 26.9777 - val_mae: 2.0331
# Epoch 49/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 25.9016 - mae: 2.0284 - val_loss: 26.9243 - val_mae: 2.0393
# Epoch 50/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 25.8488 - mae: 2.0345 - val_loss: 26.8732 - val_mae: 2.0453
# Epoch 51/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 25.7998 - mae: 2.0407 - val_loss: 26.8236 - val_mae: 2.0513
# Epoch 52/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 25.7508 - mae: 2.0467 - val_loss: 26.7763 - val_mae: 2.0571
# Epoch 53/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 25.7037 - mae: 2.0525 - val_loss: 26.7310 - val_mae: 2.0626
# Epoch 54/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 25.6596 - mae: 2.0581 - val_loss: 26.6871 - val_mae: 2.0680
# Epoch 55/1600
# 4/4 [==============================] - 0s 74ms/step - loss: 25.6159 - mae: 2.0636 - val_loss: 26.6449 - val_mae: 2.0733
# Epoch 56/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 25.5760 - mae: 2.0691 - val_loss: 26.6037 - val_mae: 2.0785
# Epoch 57/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 25.5350 - mae: 2.0743 - val_loss: 26.5641 - val_mae: 2.0834
# Epoch 58/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 25.4961 - mae: 2.0793 - val_loss: 26.5259 - val_mae: 2.0883
# Epoch 59/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 25.4586 - mae: 2.0842 - val_loss: 26.4889 - val_mae: 2.0929
# Epoch 60/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 25.4217 - mae: 2.0888 - val_loss: 26.4533 - val_mae: 2.0974
# Epoch 61/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 25.3874 - mae: 2.0934 - val_loss: 26.4183 - val_mae: 2.1018
# Epoch 62/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 25.3531 - mae: 2.0978 - val_loss: 26.3844 - val_mae: 2.1060
# Epoch 63/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 25.3198 - mae: 2.1021 - val_loss: 26.3515 - val_mae: 2.1100
# Epoch 64/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 25.2872 - mae: 2.1061 - val_loss: 26.3196 - val_mae: 2.1139
# Epoch 65/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 25.2561 - mae: 2.1100 - val_loss: 26.2884 - val_mae: 2.1177
# Epoch 66/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 25.2254 - mae: 2.1138 - val_loss: 26.2580 - val_mae: 2.1213
# Epoch 67/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 25.1955 - mae: 2.1176 - val_loss: 26.2285 - val_mae: 2.1249
# Epoch 68/1600
# 4/4 [==============================] - 0s 90ms/step - loss: 25.1666 - mae: 2.1212 - val_loss: 26.1996 - val_mae: 2.1283
# Epoch 69/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 25.1379 - mae: 2.1246 - val_loss: 26.1716 - val_mae: 2.1315
# Epoch 70/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 25.1108 - mae: 2.1280 - val_loss: 26.1440 - val_mae: 2.1348
# Epoch 71/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 25.0838 - mae: 2.1313 - val_loss: 26.1170 - val_mae: 2.1379
# Epoch 72/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 25.0572 - mae: 2.1343 - val_loss: 26.0908 - val_mae: 2.1409
# Epoch 73/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 25.0312 - mae: 2.1374 - val_loss: 26.0652 - val_mae: 2.1437
# Epoch 74/1600
# 4/4 [==============================] - 0s 87ms/step - loss: 25.0063 - mae: 2.1402 - val_loss: 26.0400 - val_mae: 2.1465
# Epoch 75/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 24.9815 - mae: 2.1431 - val_loss: 26.0154 - val_mae: 2.1492
# Epoch 76/1600
# 4/4 [==============================] - 0s 90ms/step - loss: 24.9575 - mae: 2.1459 - val_loss: 25.9912 - val_mae: 2.1519
# Epoch 77/1600
# 4/4 [==============================] - 0s 87ms/step - loss: 24.9339 - mae: 2.1485 - val_loss: 25.9675 - val_mae: 2.1545
# Epoch 78/1600
# 4/4 [==============================] - 0s 87ms/step - loss: 24.9105 - mae: 2.1512 - val_loss: 25.9443 - val_mae: 2.1569
# Epoch 79/1600
# 4/4 [==============================] - 0s 86ms/step - loss: 24.8877 - mae: 2.1537 - val_loss: 25.9215 - val_mae: 2.1593
# Epoch 80/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 24.8651 - mae: 2.1561 - val_loss: 25.8993 - val_mae: 2.1616
# Epoch 81/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.8435 - mae: 2.1584 - val_loss: 25.8773 - val_mae: 2.1638
# Epoch 82/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 24.8217 - mae: 2.1606 - val_loss: 25.8558 - val_mae: 2.1660
# Epoch 83/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 24.8009 - mae: 2.1629 - val_loss: 25.8345 - val_mae: 2.1681
# Epoch 84/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 24.7800 - mae: 2.1651 - val_loss: 25.8137 - val_mae: 2.1701
# Epoch 85/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 24.7599 - mae: 2.1672 - val_loss: 25.7931 - val_mae: 2.1722
# Epoch 86/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.7397 - mae: 2.1693 - val_loss: 25.7729 - val_mae: 2.1742
# Epoch 87/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.7198 - mae: 2.1713 - val_loss: 25.7531 - val_mae: 2.1760
# Epoch 88/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.7007 - mae: 2.1733 - val_loss: 25.7336 - val_mae: 2.1779
# Epoch 89/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.6810 - mae: 2.1751 - val_loss: 25.7146 - val_mae: 2.1795
# Epoch 90/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.6627 - mae: 2.1768 - val_loss: 25.6957 - val_mae: 2.1812
# Epoch 91/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.6444 - mae: 2.1786 - val_loss: 25.6770 - val_mae: 2.1828
# Epoch 92/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.6259 - mae: 2.1802 - val_loss: 25.6587 - val_mae: 2.1844
# Epoch 93/1600
# 4/4 [==============================] - 0s 72ms/step - loss: 24.6078 - mae: 2.1817 - val_loss: 25.6407 - val_mae: 2.1858
# Epoch 94/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.5903 - mae: 2.1833 - val_loss: 25.6229 - val_mae: 2.1872
# Epoch 95/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.5727 - mae: 2.1847 - val_loss: 25.6054 - val_mae: 2.1886
# Epoch 96/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 24.5559 - mae: 2.1862 - val_loss: 25.5879 - val_mae: 2.1900
# Epoch 97/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.5384 - mae: 2.1877 - val_loss: 25.5709 - val_mae: 2.1913
# Epoch 98/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.5219 - mae: 2.1890 - val_loss: 25.5540 - val_mae: 2.1926
# Epoch 99/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.5057 - mae: 2.1904 - val_loss: 25.5372 - val_mae: 2.1939
# Epoch 100/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.4888 - mae: 2.1917 - val_loss: 25.5209 - val_mae: 2.1950
# Epoch 101/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.4730 - mae: 2.1929 - val_loss: 25.5046 - val_mae: 2.1962
# Epoch 102/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.4569 - mae: 2.1941 - val_loss: 25.4885 - val_mae: 2.1972
# Epoch 103/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.4413 - mae: 2.1953 - val_loss: 25.4726 - val_mae: 2.1983
# Epoch 104/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.4254 - mae: 2.1963 - val_loss: 25.4570 - val_mae: 2.1993
# Epoch 105/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.4101 - mae: 2.1973 - val_loss: 25.4415 - val_mae: 2.2002
# Epoch 106/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 24.3954 - mae: 2.1983 - val_loss: 25.4260 - val_mae: 2.2012
# Epoch 107/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.3799 - mae: 2.1994 - val_loss: 25.4108 - val_mae: 2.2021
# Epoch 108/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.3652 - mae: 2.2002 - val_loss: 25.3957 - val_mae: 2.2030
# Epoch 109/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 24.3502 - mae: 2.2011 - val_loss: 25.3808 - val_mae: 2.2037
# Epoch 110/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.3357 - mae: 2.2019 - val_loss: 25.3661 - val_mae: 2.2045
# Epoch 111/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.3212 - mae: 2.2027 - val_loss: 25.3515 - val_mae: 2.2052
# Epoch 112/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 24.3071 - mae: 2.2035 - val_loss: 25.3369 - val_mae: 2.2060
# Epoch 113/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 24.2926 - mae: 2.2042 - val_loss: 25.3226 - val_mae: 2.2067
# Epoch 114/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.2784 - mae: 2.2049 - val_loss: 25.3085 - val_mae: 2.2072
# Epoch 115/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.2647 - mae: 2.2055 - val_loss: 25.2943 - val_mae: 2.2079
# Epoch 116/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.2508 - mae: 2.2062 - val_loss: 25.2803 - val_mae: 2.2085
# Epoch 117/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.2372 - mae: 2.2068 - val_loss: 25.2663 - val_mae: 2.2092
# Epoch 118/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 24.2237 - mae: 2.2075 - val_loss: 25.2524 - val_mae: 2.2098
# Epoch 119/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 24.2099 - mae: 2.2081 - val_loss: 25.2387 - val_mae: 2.2102
# Epoch 120/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 24.1966 - mae: 2.2086 - val_loss: 25.2251 - val_mae: 2.2107
# Epoch 121/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 24.1830 - mae: 2.2090 - val_loss: 25.2117 - val_mae: 2.2111
# Epoch 122/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 24.1699 - mae: 2.2094 - val_loss: 25.1983 - val_mae: 2.2114
# Epoch 123/1600
# 4/4 [==============================] - 0s 91ms/step - loss: 24.1567 - mae: 2.2097 - val_loss: 25.1850 - val_mae: 2.2118
# Epoch 124/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 24.1437 - mae: 2.2102 - val_loss: 25.1717 - val_mae: 2.2121
# Epoch 125/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 24.1310 - mae: 2.2106 - val_loss: 25.1584 - val_mae: 2.2126
# Epoch 126/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 24.1176 - mae: 2.2109 - val_loss: 25.1454 - val_mae: 2.2128
# Epoch 127/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 24.1048 - mae: 2.2111 - val_loss: 25.1325 - val_mae: 2.2129
# Epoch 128/1600
# 4/4 [==============================] - 0s 91ms/step - loss: 24.0923 - mae: 2.2113 - val_loss: 25.1194 - val_mae: 2.2131
# Epoch 129/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 24.0792 - mae: 2.2115 - val_loss: 25.1066 - val_mae: 2.2133
# Epoch 130/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 24.0666 - mae: 2.2116 - val_loss: 25.0938 - val_mae: 2.2134
# Epoch 131/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 24.0542 - mae: 2.2118 - val_loss: 25.0810 - val_mae: 2.2136
# Epoch 132/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 24.0418 - mae: 2.2121 - val_loss: 25.0681 - val_mae: 2.2138
# Epoch 133/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.0290 - mae: 2.2122 - val_loss: 25.0554 - val_mae: 2.2139
# Epoch 134/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.0165 - mae: 2.2124 - val_loss: 25.0428 - val_mae: 2.2140
# Epoch 135/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 24.0039 - mae: 2.2124 - val_loss: 25.0302 - val_mae: 2.2140
# Epoch 136/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.9915 - mae: 2.2124 - val_loss: 25.0177 - val_mae: 2.2140
# Epoch 137/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.9794 - mae: 2.2124 - val_loss: 25.0050 - val_mae: 2.2140
# Epoch 138/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.9671 - mae: 2.2125 - val_loss: 24.9924 - val_mae: 2.2141
# Epoch 139/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.9545 - mae: 2.2125 - val_loss: 24.9800 - val_mae: 2.2140
# Epoch 140/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.9424 - mae: 2.2124 - val_loss: 24.9675 - val_mae: 2.2139
# Epoch 141/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.9297 - mae: 2.2123 - val_loss: 24.9551 - val_mae: 2.2137
# Epoch 142/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.9178 - mae: 2.2121 - val_loss: 24.9426 - val_mae: 2.2136
# Epoch 143/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.9053 - mae: 2.2119 - val_loss: 24.9302 - val_mae: 2.2134
# Epoch 144/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.8934 - mae: 2.2119 - val_loss: 24.9176 - val_mae: 2.2134
# Epoch 145/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.8809 - mae: 2.2118 - val_loss: 24.9051 - val_mae: 2.2132
# Epoch 146/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.8686 - mae: 2.2116 - val_loss: 24.8927 - val_mae: 2.2130
# Epoch 147/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.8561 - mae: 2.2113 - val_loss: 24.8803 - val_mae: 2.2126
# Epoch 148/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.8441 - mae: 2.2110 - val_loss: 24.8678 - val_mae: 2.2124
# Epoch 149/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.8316 - mae: 2.2108 - val_loss: 24.8554 - val_mae: 2.2121
# Epoch 150/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.8195 - mae: 2.2105 - val_loss: 24.8429 - val_mae: 2.2118
# Epoch 151/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.8069 - mae: 2.2102 - val_loss: 24.8304 - val_mae: 2.2114
# Epoch 152/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.7948 - mae: 2.2098 - val_loss: 24.8179 - val_mae: 2.2111
# Epoch 153/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.7824 - mae: 2.2095 - val_loss: 24.8053 - val_mae: 2.2107
# Epoch 154/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.7698 - mae: 2.2091 - val_loss: 24.7927 - val_mae: 2.2103
# Epoch 155/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 23.7573 - mae: 2.2085 - val_loss: 24.7801 - val_mae: 2.2097
# Epoch 156/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.7449 - mae: 2.2080 - val_loss: 24.7674 - val_mae: 2.2092
# Epoch 157/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.7323 - mae: 2.2076 - val_loss: 24.7547 - val_mae: 2.2087
# Epoch 158/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.7197 - mae: 2.2070 - val_loss: 24.7420 - val_mae: 2.2081
# Epoch 159/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.7070 - mae: 2.2064 - val_loss: 24.7292 - val_mae: 2.2075
# Epoch 160/1600
# 4/4 [==============================] - 0s 78ms/step - loss: 23.6942 - mae: 2.2057 - val_loss: 24.7164 - val_mae: 2.2068
# Epoch 161/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.6815 - mae: 2.2050 - val_loss: 24.7035 - val_mae: 2.2062
# Epoch 162/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.6688 - mae: 2.2044 - val_loss: 24.6905 - val_mae: 2.2056
# Epoch 163/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.6560 - mae: 2.2039 - val_loss: 24.6774 - val_mae: 2.2050
# Epoch 164/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.6427 - mae: 2.2033 - val_loss: 24.6643 - val_mae: 2.2043
# Epoch 165/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.6296 - mae: 2.2024 - val_loss: 24.6512 - val_mae: 2.2035
# Epoch 166/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.6166 - mae: 2.2017 - val_loss: 24.6380 - val_mae: 2.2028
# Epoch 167/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.6037 - mae: 2.2011 - val_loss: 24.6245 - val_mae: 2.2022
# Epoch 168/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 23.5900 - mae: 2.2004 - val_loss: 24.6111 - val_mae: 2.2014
# Epoch 169/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 23.5766 - mae: 2.1996 - val_loss: 24.5976 - val_mae: 2.2006
# Epoch 170/1600
# 4/4 [==============================] - 0s 92ms/step - loss: 23.5631 - mae: 2.1987 - val_loss: 24.5840 - val_mae: 2.1997
# Epoch 171/1600
# 4/4 [==============================] - 0s 106ms/step - loss: 23.5497 - mae: 2.1979 - val_loss: 24.5702 - val_mae: 2.1990
# Epoch 172/1600
# 4/4 [==============================] - 0s 89ms/step - loss: 23.5358 - mae: 2.1972 - val_loss: 24.5564 - val_mae: 2.1982
# Epoch 173/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 23.5221 - mae: 2.1963 - val_loss: 24.5425 - val_mae: 2.1973
# Epoch 174/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 23.5083 - mae: 2.1956 - val_loss: 24.5285 - val_mae: 2.1966
# Epoch 175/1600
# 4/4 [==============================] - 0s 93ms/step - loss: 23.4941 - mae: 2.1947 - val_loss: 24.5144 - val_mae: 2.1957
# Epoch 176/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 23.4799 - mae: 2.1937 - val_loss: 24.5002 - val_mae: 2.1946
# Epoch 177/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 23.4657 - mae: 2.1927 - val_loss: 24.4859 - val_mae: 2.1936
# Epoch 178/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 23.4513 - mae: 2.1916 - val_loss: 24.4715 - val_mae: 2.1925
# Epoch 179/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 23.4370 - mae: 2.1905 - val_loss: 24.4570 - val_mae: 2.1915
# Epoch 180/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 23.4222 - mae: 2.1894 - val_loss: 24.4424 - val_mae: 2.1904
# Epoch 181/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 23.4077 - mae: 2.1884 - val_loss: 24.4276 - val_mae: 2.1894
# Epoch 182/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 23.3928 - mae: 2.1873 - val_loss: 24.4128 - val_mae: 2.1883
# Epoch 183/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 23.3780 - mae: 2.1863 - val_loss: 24.3978 - val_mae: 2.1873
# Epoch 184/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.3628 - mae: 2.1852 - val_loss: 24.3828 - val_mae: 2.1862
# Epoch 185/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.3477 - mae: 2.1841 - val_loss: 24.3676 - val_mae: 2.1850
# Epoch 186/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.3325 - mae: 2.1829 - val_loss: 24.3523 - val_mae: 2.1839
# Epoch 187/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.3169 - mae: 2.1817 - val_loss: 24.3369 - val_mae: 2.1827
# Epoch 188/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.3014 - mae: 2.1805 - val_loss: 24.3215 - val_mae: 2.1815
# Epoch 189/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 23.2859 - mae: 2.1793 - val_loss: 24.3059 - val_mae: 2.1802
# Epoch 190/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 23.2702 - mae: 2.1780 - val_loss: 24.2902 - val_mae: 2.1791
# Epoch 191/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.2544 - mae: 2.1769 - val_loss: 24.2745 - val_mae: 2.1780
# Epoch 192/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.2385 - mae: 2.1758 - val_loss: 24.2586 - val_mae: 2.1769
# Epoch 193/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.2224 - mae: 2.1746 - val_loss: 24.2426 - val_mae: 2.1756
# Epoch 194/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.2061 - mae: 2.1733 - val_loss: 24.2266 - val_mae: 2.1743
# Epoch 195/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.1901 - mae: 2.1721 - val_loss: 24.2104 - val_mae: 2.1732
# Epoch 196/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.1737 - mae: 2.1709 - val_loss: 24.1941 - val_mae: 2.1719
# Epoch 197/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.1574 - mae: 2.1695 - val_loss: 24.1778 - val_mae: 2.1706
# Epoch 198/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.1408 - mae: 2.1682 - val_loss: 24.1614 - val_mae: 2.1693
# Epoch 199/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.1242 - mae: 2.1669 - val_loss: 24.1449 - val_mae: 2.1680
# Epoch 200/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.1076 - mae: 2.1655 - val_loss: 24.1284 - val_mae: 2.1666
# Epoch 201/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.0908 - mae: 2.1641 - val_loss: 24.1118 - val_mae: 2.1654
# Epoch 202/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.0738 - mae: 2.1628 - val_loss: 24.0952 - val_mae: 2.1640
# Epoch 203/1600
# 4/4 [==============================] - 0s 79ms/step - loss: 23.0572 - mae: 2.1614 - val_loss: 24.0784 - val_mae: 2.1627
# Epoch 204/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 23.0404 - mae: 2.1602 - val_loss: 24.0616 - val_mae: 2.1616
# Epoch 205/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.0235 - mae: 2.1591 - val_loss: 24.0446 - val_mae: 2.1607
# Epoch 206/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 23.0064 - mae: 2.1581 - val_loss: 24.0277 - val_mae: 2.1595
# Epoch 207/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.9890 - mae: 2.1567 - val_loss: 24.0109 - val_mae: 2.1581
# Epoch 208/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 22.9722 - mae: 2.1552 - val_loss: 23.9940 - val_mae: 2.1566
# Epoch 209/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 22.9553 - mae: 2.1540 - val_loss: 23.9769 - val_mae: 2.1556
# Epoch 210/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 22.9379 - mae: 2.1526 - val_loss: 23.9599 - val_mae: 2.1542
# Epoch 211/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 22.9209 - mae: 2.1514 - val_loss: 23.9429 - val_mae: 2.1530
# Epoch 212/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.9036 - mae: 2.1500 - val_loss: 23.9259 - val_mae: 2.1516
# Epoch 213/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.8864 - mae: 2.1485 - val_loss: 23.9089 - val_mae: 2.1502
# Epoch 214/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.8697 - mae: 2.1473 - val_loss: 23.8918 - val_mae: 2.1492
# Epoch 215/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.8521 - mae: 2.1461 - val_loss: 23.8748 - val_mae: 2.1478
# Epoch 216/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.8348 - mae: 2.1447 - val_loss: 23.8578 - val_mae: 2.1465
# Epoch 217/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.8177 - mae: 2.1433 - val_loss: 23.8408 - val_mae: 2.1451
# Epoch 218/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 22.8004 - mae: 2.1418 - val_loss: 23.8238 - val_mae: 2.1436
# Epoch 219/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 22.7837 - mae: 2.1405 - val_loss: 23.8066 - val_mae: 2.1427
# Epoch 220/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 22.7661 - mae: 2.1393 - val_loss: 23.7896 - val_mae: 2.1413
# Epoch 221/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 22.7490 - mae: 2.1378 - val_loss: 23.7726 - val_mae: 2.1399
# Epoch 222/1600
# 4/4 [==============================] - 0s 86ms/step - loss: 22.7319 - mae: 2.1365 - val_loss: 23.7556 - val_mae: 2.1385
# Epoch 223/1600
# 4/4 [==============================] - 0s 97ms/step - loss: 22.7148 - mae: 2.1350 - val_loss: 23.7385 - val_mae: 2.1373
# Epoch 224/1600
# 4/4 [==============================] - 0s 87ms/step - loss: 22.6975 - mae: 2.1337 - val_loss: 23.7215 - val_mae: 2.1360
# Epoch 225/1600
# 4/4 [==============================] - 0s 86ms/step - loss: 22.6803 - mae: 2.1324 - val_loss: 23.7046 - val_mae: 2.1348
# Epoch 226/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 22.6634 - mae: 2.1312 - val_loss: 23.6876 - val_mae: 2.1336
# Epoch 227/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 22.6462 - mae: 2.1299 - val_loss: 23.6706 - val_mae: 2.1322
# Epoch 228/1600
# 4/4 [==============================] - 0s 86ms/step - loss: 22.6292 - mae: 2.1285 - val_loss: 23.6536 - val_mae: 2.1311
# Epoch 229/1600
# 4/4 [==============================] - 0s 88ms/step - loss: 22.6119 - mae: 2.1272 - val_loss: 23.6367 - val_mae: 2.1297
# Epoch 230/1600
# 4/4 [==============================] - 0s 90ms/step - loss: 22.5950 - mae: 2.1258 - val_loss: 23.6197 - val_mae: 2.1285
# Epoch 231/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 22.5778 - mae: 2.1244 - val_loss: 23.6028 - val_mae: 2.1270
# Epoch 232/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 22.5609 - mae: 2.1228 - val_loss: 23.5859 - val_mae: 2.1256
# Epoch 233/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 22.5439 - mae: 2.1214 - val_loss: 23.5690 - val_mae: 2.1243
# Epoch 234/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 22.5268 - mae: 2.1201 - val_loss: 23.5521 - val_mae: 2.1230
# Epoch 235/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.5100 - mae: 2.1189 - val_loss: 23.5351 - val_mae: 2.1219
# Epoch 236/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.4930 - mae: 2.1175 - val_loss: 23.5181 - val_mae: 2.1206
# Epoch 237/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 22.4759 - mae: 2.1161 - val_loss: 23.5012 - val_mae: 2.1193
# Epoch 238/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 22.4586 - mae: 2.1146 - val_loss: 23.4843 - val_mae: 2.1176
# Epoch 239/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 22.4417 - mae: 2.1129 - val_loss: 23.4674 - val_mae: 2.1162
# Epoch 240/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.4250 - mae: 2.1115 - val_loss: 23.4503 - val_mae: 2.1148
# Epoch 241/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.4080 - mae: 2.1102 - val_loss: 23.4333 - val_mae: 2.1136
# Epoch 242/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.3906 - mae: 2.1086 - val_loss: 23.4164 - val_mae: 2.1119
# Epoch 243/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.3738 - mae: 2.1070 - val_loss: 23.3994 - val_mae: 2.1106
# Epoch 244/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.3568 - mae: 2.1056 - val_loss: 23.3824 - val_mae: 2.1093
# Epoch 245/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.3398 - mae: 2.1043 - val_loss: 23.3654 - val_mae: 2.1081
# Epoch 246/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.3229 - mae: 2.1031 - val_loss: 23.3482 - val_mae: 2.1068
# Epoch 247/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.3054 - mae: 2.1014 - val_loss: 23.3313 - val_mae: 2.1051
# Epoch 248/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.2886 - mae: 2.0997 - val_loss: 23.3142 - val_mae: 2.1036
# Epoch 249/1600
# 4/4 [==============================] - 0s 69ms/step - loss: 22.2715 - mae: 2.0982 - val_loss: 23.2971 - val_mae: 2.1021
# Epoch 250/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.2547 - mae: 2.0968 - val_loss: 23.2799 - val_mae: 2.1009
# Epoch 251/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 22.2376 - mae: 2.0955 - val_loss: 23.2626 - val_mae: 2.0996
# Epoch 252/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 22.2203 - mae: 2.0942 - val_loss: 23.2454 - val_mae: 2.0983
# Epoch 253/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.2031 - mae: 2.0926 - val_loss: 23.2282 - val_mae: 2.0968
# Epoch 254/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.1860 - mae: 2.0912 - val_loss: 23.2110 - val_mae: 2.0955
# Epoch 255/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.1686 - mae: 2.0896 - val_loss: 23.1938 - val_mae: 2.0937
# Epoch 256/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 22.1517 - mae: 2.0880 - val_loss: 23.1765 - val_mae: 2.0925
# Epoch 257/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.1344 - mae: 2.0865 - val_loss: 23.1593 - val_mae: 2.0909
# Epoch 258/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.1173 - mae: 2.0849 - val_loss: 23.1419 - val_mae: 2.0894
# Epoch 259/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.1000 - mae: 2.0833 - val_loss: 23.1245 - val_mae: 2.0879
# Epoch 260/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 22.0824 - mae: 2.0817 - val_loss: 23.1072 - val_mae: 2.0863
# Epoch 261/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 22.0653 - mae: 2.0801 - val_loss: 23.0898 - val_mae: 2.0848
# Epoch 262/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.0476 - mae: 2.0783 - val_loss: 23.0725 - val_mae: 2.0829
# Epoch 263/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 22.0306 - mae: 2.0767 - val_loss: 23.0550 - val_mae: 2.0817
# Epoch 264/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 22.0133 - mae: 2.0753 - val_loss: 23.0374 - val_mae: 2.0802
# Epoch 265/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.9958 - mae: 2.0737 - val_loss: 23.0199 - val_mae: 2.0789
# Epoch 266/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.9781 - mae: 2.0723 - val_loss: 23.0023 - val_mae: 2.0774
# Epoch 267/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.9606 - mae: 2.0707 - val_loss: 22.9848 - val_mae: 2.0758
# Epoch 268/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.9431 - mae: 2.0690 - val_loss: 22.9672 - val_mae: 2.0743
# Epoch 269/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 21.9257 - mae: 2.0675 - val_loss: 22.9495 - val_mae: 2.0728
# Epoch 270/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 21.9077 - mae: 2.0658 - val_loss: 22.9318 - val_mae: 2.0713
# Epoch 271/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 21.8901 - mae: 2.0643 - val_loss: 22.9141 - val_mae: 2.0698
# Epoch 272/1600
# 4/4 [==============================] - 0s 101ms/step - loss: 21.8726 - mae: 2.0629 - val_loss: 22.8963 - val_mae: 2.0685
# Epoch 273/1600
# 4/4 [==============================] - 0s 86ms/step - loss: 21.8546 - mae: 2.0613 - val_loss: 22.8784 - val_mae: 2.0670
# Epoch 274/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 21.8370 - mae: 2.0598 - val_loss: 22.8604 - val_mae: 2.0656
# Epoch 275/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 21.8190 - mae: 2.0583 - val_loss: 22.8425 - val_mae: 2.0640
# Epoch 276/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.8016 - mae: 2.0569 - val_loss: 22.8244 - val_mae: 2.0629
# Epoch 277/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 21.7830 - mae: 2.0554 - val_loss: 22.8064 - val_mae: 2.0611
# Epoch 278/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.7653 - mae: 2.0536 - val_loss: 22.7883 - val_mae: 2.0596
# Epoch 279/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.7469 - mae: 2.0517 - val_loss: 22.7704 - val_mae: 2.0574
# Epoch 280/1600
# 4/4 [==============================] - 0s 74ms/step - loss: 21.7294 - mae: 2.0500 - val_loss: 22.7520 - val_mae: 2.0564
# Epoch 281/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 21.7111 - mae: 2.0486 - val_loss: 22.7338 - val_mae: 2.0550
# Epoch 282/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 21.6929 - mae: 2.0472 - val_loss: 22.7156 - val_mae: 2.0535
# Epoch 283/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 21.6745 - mae: 2.0456 - val_loss: 22.6972 - val_mae: 2.0521
# Epoch 284/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.6561 - mae: 2.0440 - val_loss: 22.6789 - val_mae: 2.0505
# Epoch 285/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.6379 - mae: 2.0423 - val_loss: 22.6605 - val_mae: 2.0489
# Epoch 286/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.6195 - mae: 2.0407 - val_loss: 22.6420 - val_mae: 2.0474
# Epoch 287/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.6008 - mae: 2.0391 - val_loss: 22.6235 - val_mae: 2.0459
# Epoch 288/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 21.5827 - mae: 2.0375 - val_loss: 22.6048 - val_mae: 2.0444
# Epoch 289/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.5640 - mae: 2.0359 - val_loss: 22.5861 - val_mae: 2.0431
# Epoch 290/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 21.5451 - mae: 2.0343 - val_loss: 22.5675 - val_mae: 2.0413
# Epoch 291/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 21.5266 - mae: 2.0326 - val_loss: 22.5487 - val_mae: 2.0398
# Epoch 292/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 21.5079 - mae: 2.0312 - val_loss: 22.5299 - val_mae: 2.0384
# Epoch 293/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.4892 - mae: 2.0296 - val_loss: 22.5109 - val_mae: 2.0370
# Epoch 294/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.4702 - mae: 2.0280 - val_loss: 22.4920 - val_mae: 2.0354
# Epoch 295/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.4515 - mae: 2.0264 - val_loss: 22.4730 - val_mae: 2.0337
# Epoch 296/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.4325 - mae: 2.0246 - val_loss: 22.4541 - val_mae: 2.0321
# Epoch 297/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.4135 - mae: 2.0231 - val_loss: 22.4349 - val_mae: 2.0306
# Epoch 298/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.3943 - mae: 2.0214 - val_loss: 22.4157 - val_mae: 2.0291
# Epoch 299/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.3753 - mae: 2.0198 - val_loss: 22.3966 - val_mae: 2.0275
# Epoch 300/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.3563 - mae: 2.0184 - val_loss: 22.3771 - val_mae: 2.0262
# Epoch 301/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.3367 - mae: 2.0168 - val_loss: 22.3578 - val_mae: 2.0246
# Epoch 302/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.3174 - mae: 2.0151 - val_loss: 22.3384 - val_mae: 2.0231
# Epoch 303/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.2982 - mae: 2.0135 - val_loss: 22.3190 - val_mae: 2.0215
# Epoch 304/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.2784 - mae: 2.0116 - val_loss: 22.2996 - val_mae: 2.0196
# Epoch 305/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.2593 - mae: 2.0100 - val_loss: 22.2800 - val_mae: 2.0182
# Epoch 306/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 21.2397 - mae: 2.0085 - val_loss: 22.2604 - val_mae: 2.0168
# Epoch 307/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 21.2202 - mae: 2.0070 - val_loss: 22.2406 - val_mae: 2.0154
# Epoch 308/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.2003 - mae: 2.0056 - val_loss: 22.2209 - val_mae: 2.0141
# Epoch 309/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 21.1809 - mae: 2.0041 - val_loss: 22.2010 - val_mae: 2.0125
# Epoch 310/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 21.1612 - mae: 2.0027 - val_loss: 22.1811 - val_mae: 2.0111
# Epoch 311/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.1409 - mae: 2.0007 - val_loss: 22.1612 - val_mae: 2.0090
# Epoch 312/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.1214 - mae: 1.9990 - val_loss: 22.1411 - val_mae: 2.0075
# Epoch 313/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.1014 - mae: 1.9972 - val_loss: 22.1210 - val_mae: 2.0057
# Epoch 314/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.0811 - mae: 1.9954 - val_loss: 22.1010 - val_mae: 2.0041
# Epoch 315/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.0609 - mae: 1.9936 - val_loss: 22.0809 - val_mae: 2.0024
# Epoch 316/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.0415 - mae: 1.9921 - val_loss: 22.0605 - val_mae: 2.0011
# Epoch 317/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 21.0207 - mae: 1.9904 - val_loss: 22.0404 - val_mae: 1.9993
# Epoch 318/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 21.0004 - mae: 1.9887 - val_loss: 22.0201 - val_mae: 1.9977
# Epoch 319/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 20.9805 - mae: 1.9873 - val_loss: 21.9996 - val_mae: 1.9967
# Epoch 320/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 20.9603 - mae: 1.9859 - val_loss: 21.9789 - val_mae: 1.9952
# Epoch 321/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 20.9397 - mae: 1.9845 - val_loss: 21.9583 - val_mae: 1.9939
# Epoch 322/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 20.9190 - mae: 1.9828 - val_loss: 21.9377 - val_mae: 1.9921
# Epoch 323/1600
# 4/4 [==============================] - 0s 86ms/step - loss: 20.8987 - mae: 1.9810 - val_loss: 21.9171 - val_mae: 1.9904
# Epoch 324/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 20.8783 - mae: 1.9795 - val_loss: 21.8964 - val_mae: 1.9890
# Epoch 325/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 20.8572 - mae: 1.9775 - val_loss: 21.8758 - val_mae: 1.9869
# Epoch 326/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 20.8367 - mae: 1.9755 - val_loss: 21.8550 - val_mae: 1.9852
# Epoch 327/1600
# 4/4 [==============================] - 0s 111ms/step - loss: 20.8160 - mae: 1.9739 - val_loss: 21.8342 - val_mae: 1.9837
# Epoch 328/1600
# 4/4 [==============================] - 0s 94ms/step - loss: 20.7956 - mae: 1.9723 - val_loss: 21.8131 - val_mae: 1.9822
# Epoch 329/1600
# 4/4 [==============================] - 0s 86ms/step - loss: 20.7741 - mae: 1.9703 - val_loss: 21.7924 - val_mae: 1.9801
# Epoch 330/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 20.7537 - mae: 1.9685 - val_loss: 21.7714 - val_mae: 1.9788
# Epoch 331/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 20.7326 - mae: 1.9670 - val_loss: 21.7505 - val_mae: 1.9772
# Epoch 332/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 20.7121 - mae: 1.9655 - val_loss: 21.7290 - val_mae: 1.9759
# Epoch 333/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 20.6909 - mae: 1.9642 - val_loss: 21.7078 - val_mae: 1.9746
# Epoch 334/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 20.6698 - mae: 1.9625 - val_loss: 21.6867 - val_mae: 1.9729
# Epoch 335/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 20.6486 - mae: 1.9608 - val_loss: 21.6654 - val_mae: 1.9713
# Epoch 336/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 20.6277 - mae: 1.9594 - val_loss: 21.6440 - val_mae: 1.9701
# Epoch 337/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 20.6058 - mae: 1.9577 - val_loss: 21.6227 - val_mae: 1.9681
# Epoch 338/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 20.5851 - mae: 1.9557 - val_loss: 21.6014 - val_mae: 1.9661
# Epoch 339/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 20.5636 - mae: 1.9539 - val_loss: 21.5800 - val_mae: 1.9647
# Epoch 340/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 20.5425 - mae: 1.9524 - val_loss: 21.5583 - val_mae: 1.9633
# Epoch 341/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 20.5210 - mae: 1.9505 - val_loss: 21.5368 - val_mae: 1.9612
# Epoch 342/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 20.4999 - mae: 1.9488 - val_loss: 21.5152 - val_mae: 1.9599
# Epoch 343/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 20.4779 - mae: 1.9473 - val_loss: 21.4937 - val_mae: 1.9584
# Epoch 344/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 20.4564 - mae: 1.9454 - val_loss: 21.4723 - val_mae: 1.9564
# Epoch 345/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 20.4354 - mae: 1.9438 - val_loss: 21.4505 - val_mae: 1.9553
# Epoch 346/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 20.4139 - mae: 1.9425 - val_loss: 21.4286 - val_mae: 1.9539
# Epoch 347/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 20.3923 - mae: 1.9410 - val_loss: 21.4068 - val_mae: 1.9523
# Epoch 348/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 20.3708 - mae: 1.9393 - val_loss: 21.3847 - val_mae: 1.9506
# Epoch 349/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 20.3488 - mae: 1.9374 - val_loss: 21.3628 - val_mae: 1.9486
# Epoch 350/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 20.3271 - mae: 1.9355 - val_loss: 21.3410 - val_mae: 1.9469
# Epoch 351/1600
# ...
# 4/4 [==============================] - 0s 81ms/step - loss: 13.2590 - mae: 1.4631 - val_loss: 13.6812 - val_mae: 1.4696
# Epoch 1340/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.2608 - mae: 1.4633 - val_loss: 13.6791 - val_mae: 1.4684
# Epoch 1341/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.2585 - mae: 1.4657 - val_loss: 13.6803 - val_mae: 1.4726
# Epoch 1342/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.2542 - mae: 1.4658 - val_loss: 13.6763 - val_mae: 1.4686
# Epoch 1343/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.2528 - mae: 1.4621 - val_loss: 13.6743 - val_mae: 1.4659
# Epoch 1344/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.2511 - mae: 1.4625 - val_loss: 13.6718 - val_mae: 1.4685
# Epoch 1345/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.2494 - mae: 1.4631 - val_loss: 13.6676 - val_mae: 1.4677
# Epoch 1346/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.2468 - mae: 1.4630 - val_loss: 13.6652 - val_mae: 1.4691
# Epoch 1347/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.2456 - mae: 1.4645 - val_loss: 13.6618 - val_mae: 1.4700
# Epoch 1348/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.2435 - mae: 1.4640 - val_loss: 13.6605 - val_mae: 1.4668
# Epoch 1349/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 13.2412 - mae: 1.4627 - val_loss: 13.6600 - val_mae: 1.4680
# Epoch 1350/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.2413 - mae: 1.4618 - val_loss: 13.6594 - val_mae: 1.4653
# Epoch 1351/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.2379 - mae: 1.4610 - val_loss: 13.6557 - val_mae: 1.4681
# Epoch 1352/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 13.2358 - mae: 1.4635 - val_loss: 13.6525 - val_mae: 1.4692
# Epoch 1353/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.2358 - mae: 1.4637 - val_loss: 13.6517 - val_mae: 1.4692
# Epoch 1354/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.2343 - mae: 1.4633 - val_loss: 13.6514 - val_mae: 1.4674
# Epoch 1355/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 13.2305 - mae: 1.4633 - val_loss: 13.6475 - val_mae: 1.4685
# Epoch 1356/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.2290 - mae: 1.4635 - val_loss: 13.6468 - val_mae: 1.4681
# Epoch 1357/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.2270 - mae: 1.4630 - val_loss: 13.6446 - val_mae: 1.4681
# Epoch 1358/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.2271 - mae: 1.4618 - val_loss: 13.6411 - val_mae: 1.4663
# Epoch 1359/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.2234 - mae: 1.4626 - val_loss: 13.6395 - val_mae: 1.4680
# Epoch 1360/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.2244 - mae: 1.4646 - val_loss: 13.6355 - val_mae: 1.4687
# Epoch 1361/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 13.2233 - mae: 1.4611 - val_loss: 13.6351 - val_mae: 1.4632
# Epoch 1362/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.2209 - mae: 1.4587 - val_loss: 13.6305 - val_mae: 1.4659
# Epoch 1363/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.2186 - mae: 1.4645 - val_loss: 13.6321 - val_mae: 1.4717
# Epoch 1364/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 13.2178 - mae: 1.4651 - val_loss: 13.6288 - val_mae: 1.4667
# Epoch 1365/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.2181 - mae: 1.4607 - val_loss: 13.6279 - val_mae: 1.4638
# Epoch 1366/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.2115 - mae: 1.4603 - val_loss: 13.6274 - val_mae: 1.4669
# Epoch 1367/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.2115 - mae: 1.4641 - val_loss: 13.6258 - val_mae: 1.4712
# Epoch 1368/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.2095 - mae: 1.4645 - val_loss: 13.6202 - val_mae: 1.4670
# Epoch 1369/1600
# 4/4 [==============================] - 0s 87ms/step - loss: 13.2078 - mae: 1.4622 - val_loss: 13.6166 - val_mae: 1.4666
# Epoch 1370/1600
# 4/4 [==============================] - 0s 86ms/step - loss: 13.2045 - mae: 1.4618 - val_loss: 13.6148 - val_mae: 1.4660
# Epoch 1371/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 13.2032 - mae: 1.4620 - val_loss: 13.6150 - val_mae: 1.4659
# Epoch 1372/1600
# 4/4 [==============================] - 0s 86ms/step - loss: 13.2012 - mae: 1.4607 - val_loss: 13.6147 - val_mae: 1.4645
# Epoch 1373/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.2015 - mae: 1.4598 - val_loss: 13.6099 - val_mae: 1.4653
# Epoch 1374/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.1975 - mae: 1.4619 - val_loss: 13.6076 - val_mae: 1.4676
# Epoch 1375/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.1959 - mae: 1.4627 - val_loss: 13.6066 - val_mae: 1.4673
# Epoch 1376/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.1932 - mae: 1.4621 - val_loss: 13.6055 - val_mae: 1.4665
# Epoch 1377/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.1931 - mae: 1.4605 - val_loss: 13.6036 - val_mae: 1.4648
# Epoch 1378/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.1899 - mae: 1.4613 - val_loss: 13.6017 - val_mae: 1.4673
# Epoch 1379/1600
# 4/4 [==============================] - 0s 91ms/step - loss: 13.1883 - mae: 1.4635 - val_loss: 13.5993 - val_mae: 1.4689
# Epoch 1380/1600
# 4/4 [==============================] - 0s 87ms/step - loss: 13.1866 - mae: 1.4636 - val_loss: 13.5960 - val_mae: 1.4664
# Epoch 1381/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 13.1851 - mae: 1.4623 - val_loss: 13.5941 - val_mae: 1.4660
# Epoch 1382/1600
# 4/4 [==============================] - 0s 90ms/step - loss: 13.1954 - mae: 1.4577 - val_loss: 13.5952 - val_mae: 1.4603
# Epoch 1383/1600
# 4/4 [==============================] - 0s 88ms/step - loss: 13.1881 - mae: 1.4600 - val_loss: 13.5904 - val_mae: 1.4685
# Epoch 1384/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 13.1824 - mae: 1.4645 - val_loss: 13.5881 - val_mae: 1.4687
# Epoch 1385/1600
# 4/4 [==============================] - 0s 88ms/step - loss: 13.1783 - mae: 1.4638 - val_loss: 13.5832 - val_mae: 1.4657
# Epoch 1386/1600
# 4/4 [==============================] - 0s 95ms/step - loss: 13.1964 - mae: 1.4570 - val_loss: 13.5915 - val_mae: 1.4578
# Epoch 1387/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 13.1813 - mae: 1.4581 - val_loss: 13.5809 - val_mae: 1.4683
# Epoch 1388/1600
# 4/4 [==============================] - 0s 86ms/step - loss: 13.1748 - mae: 1.4659 - val_loss: 13.5828 - val_mae: 1.4718
# Epoch 1389/1600
# 4/4 [==============================] - 0s 91ms/step - loss: 13.1742 - mae: 1.4656 - val_loss: 13.5761 - val_mae: 1.4670
# Epoch 1390/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.1716 - mae: 1.4625 - val_loss: 13.5731 - val_mae: 1.4649
# Epoch 1391/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 13.1692 - mae: 1.4586 - val_loss: 13.5719 - val_mae: 1.4610
# Epoch 1392/1600
# 4/4 [==============================] - 0s 86ms/step - loss: 13.1676 - mae: 1.4571 - val_loss: 13.5713 - val_mae: 1.4627
# Epoch 1393/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.1684 - mae: 1.4611 - val_loss: 13.5716 - val_mae: 1.4689
# Epoch 1394/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.1642 - mae: 1.4640 - val_loss: 13.5701 - val_mae: 1.4669
# Epoch 1395/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.1624 - mae: 1.4606 - val_loss: 13.5686 - val_mae: 1.4621
# Epoch 1396/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.1627 - mae: 1.4570 - val_loss: 13.5661 - val_mae: 1.4619
# Epoch 1397/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.1587 - mae: 1.4595 - val_loss: 13.5635 - val_mae: 1.4664
# Epoch 1398/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.1572 - mae: 1.4624 - val_loss: 13.5610 - val_mae: 1.4674
# Epoch 1399/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.1567 - mae: 1.4639 - val_loss: 13.5594 - val_mae: 1.4672
# Epoch 1400/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.1560 - mae: 1.4606 - val_loss: 13.5581 - val_mae: 1.4629
# Epoch 1401/1600
# 4/4 [==============================] - 0s 69ms/step - loss: 13.1536 - mae: 1.4580 - val_loss: 13.5582 - val_mae: 1.4620
# Epoch 1402/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.1510 - mae: 1.4581 - val_loss: 13.5546 - val_mae: 1.4649
# Epoch 1403/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.1487 - mae: 1.4615 - val_loss: 13.5520 - val_mae: 1.4668
# Epoch 1404/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.1477 - mae: 1.4622 - val_loss: 13.5490 - val_mae: 1.4650
# Epoch 1405/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.1453 - mae: 1.4611 - val_loss: 13.5480 - val_mae: 1.4642
# Epoch 1406/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.1465 - mae: 1.4610 - val_loss: 13.5465 - val_mae: 1.4646
# Epoch 1407/1600
# 4/4 [==============================] - 0s 84ms/step - loss: 13.1421 - mae: 1.4602 - val_loss: 13.5443 - val_mae: 1.4621
# Epoch 1408/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 13.1409 - mae: 1.4582 - val_loss: 13.5411 - val_mae: 1.4620
# Epoch 1409/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.1405 - mae: 1.4579 - val_loss: 13.5383 - val_mae: 1.4617
# Epoch 1410/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.1369 - mae: 1.4582 - val_loss: 13.5381 - val_mae: 1.4635
# Epoch 1411/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.1381 - mae: 1.4609 - val_loss: 13.5394 - val_mae: 1.4670
# Epoch 1412/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.1353 - mae: 1.4611 - val_loss: 13.5395 - val_mae: 1.4631
# Epoch 1413/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.1318 - mae: 1.4585 - val_loss: 13.5357 - val_mae: 1.4628
# Epoch 1414/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.1346 - mae: 1.4570 - val_loss: 13.5338 - val_mae: 1.4629
# Epoch 1415/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.1300 - mae: 1.4607 - val_loss: 13.5305 - val_mae: 1.4678
# Epoch 1416/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.1286 - mae: 1.4625 - val_loss: 13.5269 - val_mae: 1.4654
# Epoch 1417/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.1263 - mae: 1.4599 - val_loss: 13.5222 - val_mae: 1.4627
# Epoch 1418/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.1274 - mae: 1.4603 - val_loss: 13.5177 - val_mae: 1.4657
# Epoch 1419/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.1247 - mae: 1.4592 - val_loss: 13.5166 - val_mae: 1.4616
# Epoch 1420/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.1212 - mae: 1.4573 - val_loss: 13.5165 - val_mae: 1.4616
# Epoch 1421/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.1193 - mae: 1.4573 - val_loss: 13.5166 - val_mae: 1.4634
# Epoch 1422/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 13.1205 - mae: 1.4602 - val_loss: 13.5182 - val_mae: 1.4654
# Epoch 1423/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 13.1171 - mae: 1.4612 - val_loss: 13.5164 - val_mae: 1.4662
# Epoch 1424/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.1154 - mae: 1.4625 - val_loss: 13.5124 - val_mae: 1.4653
# Epoch 1425/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.1109 - mae: 1.4593 - val_loss: 13.5104 - val_mae: 1.4606
# Epoch 1426/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 13.1166 - mae: 1.4547 - val_loss: 13.5106 - val_mae: 1.4585
# Epoch 1427/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 13.1108 - mae: 1.4559 - val_loss: 13.5061 - val_mae: 1.4631
# Epoch 1428/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.1113 - mae: 1.4619 - val_loss: 13.5040 - val_mae: 1.4693
# Epoch 1429/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 13.1095 - mae: 1.4632 - val_loss: 13.5011 - val_mae: 1.4646
# Epoch 1430/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 13.1052 - mae: 1.4583 - val_loss: 13.5000 - val_mae: 1.4597
# Epoch 1431/1600
# 4/4 [==============================] - 0s 76ms/step - loss: 13.1060 - mae: 1.4548 - val_loss: 13.5002 - val_mae: 1.4597
# Epoch 1432/1600
# 4/4 [==============================] - 0s 92ms/step - loss: 13.1029 - mae: 1.4570 - val_loss: 13.4987 - val_mae: 1.4643
# Epoch 1433/1600
# 4/4 [==============================] - 0s 90ms/step - loss: 13.1033 - mae: 1.4590 - val_loss: 13.4953 - val_mae: 1.4633
# Epoch 1434/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 13.0985 - mae: 1.4595 - val_loss: 13.4937 - val_mae: 1.4651
# Epoch 1435/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 13.0971 - mae: 1.4606 - val_loss: 13.4904 - val_mae: 1.4650
# Epoch 1436/1600
# 4/4 [==============================] - 0s 89ms/step - loss: 13.0963 - mae: 1.4603 - val_loss: 13.4873 - val_mae: 1.4637
# Epoch 1437/1600
# 4/4 [==============================] - 0s 92ms/step - loss: 13.0946 - mae: 1.4603 - val_loss: 13.4840 - val_mae: 1.4640
# Epoch 1438/1600
# 4/4 [==============================] - 0s 87ms/step - loss: 13.0938 - mae: 1.4593 - val_loss: 13.4829 - val_mae: 1.4623
# Epoch 1439/1600
# 4/4 [==============================] - 0s 88ms/step - loss: 13.0919 - mae: 1.4566 - val_loss: 13.4843 - val_mae: 1.4594
# Epoch 1440/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 13.0899 - mae: 1.4555 - val_loss: 13.4831 - val_mae: 1.4600
# Epoch 1441/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 13.0911 - mae: 1.4584 - val_loss: 13.4815 - val_mae: 1.4655
# Epoch 1442/1600
# 4/4 [==============================] - 0s 86ms/step - loss: 13.0893 - mae: 1.4618 - val_loss: 13.4791 - val_mae: 1.4640
# Epoch 1443/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 13.0824 - mae: 1.4583 - val_loss: 13.4790 - val_mae: 1.4588
# Epoch 1444/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.0847 - mae: 1.4540 - val_loss: 13.4793 - val_mae: 1.4577
# Epoch 1445/1600
# 4/4 [==============================] - 0s 83ms/step - loss: 13.0870 - mae: 1.4541 - val_loss: 13.4755 - val_mae: 1.4609
# Epoch 1446/1600
# 4/4 [==============================] - 0s 85ms/step - loss: 13.0770 - mae: 1.4593 - val_loss: 13.4743 - val_mae: 1.4692
# Epoch 1447/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.0821 - mae: 1.4645 - val_loss: 13.4719 - val_mae: 1.4694
# Epoch 1448/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.0804 - mae: 1.4646 - val_loss: 13.4667 - val_mae: 1.4652
# Epoch 1449/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.0769 - mae: 1.4571 - val_loss: 13.4685 - val_mae: 1.4561
# Epoch 1450/1600
# 4/4 [==============================] - 0s 81ms/step - loss: 13.0760 - mae: 1.4520 - val_loss: 13.4648 - val_mae: 1.4572
# Epoch 1451/1600
# 4/4 [==============================] - 0s 82ms/step - loss: 13.0795 - mae: 1.4570 - val_loss: 13.4603 - val_mae: 1.4636
# Epoch 1452/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.0776 - mae: 1.4575 - val_loss: 13.4609 - val_mae: 1.4595
# Epoch 1453/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.0717 - mae: 1.4577 - val_loss: 13.4605 - val_mae: 1.4639
# Epoch 1454/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.0694 - mae: 1.4601 - val_loss: 13.4579 - val_mae: 1.4628
# Epoch 1455/1600
# 4/4 [==============================] - 0s 80ms/step - loss: 13.0652 - mae: 1.4579 - val_loss: 13.4568 - val_mae: 1.4606
# Epoch 1456/1600
# 4/4 [==============================] - ETA: 0s - loss: 13.0671 - mae: 1.4549
